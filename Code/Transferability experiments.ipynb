# %%
import pandas as pd
import tsfresh
import os
import json
import scapy
import numpy as np
import warnings
from timeit import default_timer as timer

from scapy.all import *

warnings.filterwarnings("ignore") #ignore warnings caused by 


#################################################################
#                                                               #
#               malicious csv files import                      #
#                                                               #
#################################################################

df1 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/WebOS_binary.csv') #
df2 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_Binary.csv') #
df3 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Webmine_Robust.csv')
df4 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Binary.csv') #
df5 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Webmine_Aggressive.csv')
df6 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Aggressive.csv')
df7 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_WebminePool_Aggressive.csv') #

df32 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_WebminePool_Robust.csv') #
df33 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Stealthy.csv') #
df34 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Robust.csv') #
df35 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Desktop_WebminePool_Aggressive.csv') #


#################################################################
#                                                               #
#               benign csv files import                         #
#                                                               #
#################################################################

############### LAPTOP #############

df8 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_download_benign.csv')
df9 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_idle_benign.csv')
df10 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_interactive_benign.csv')
df11 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_video_benign.csv')
df12 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_webbrowsing_benign.csv')

############### Raspberry ##########

df13 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_download_benign.csv')
df14 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_idle_benign.csv')
df15 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_interactive_benign.csv')
df16 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_video_benign.csv')
df17 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_webbrowsing_benign.csv')

############### Server ############


df18 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_download_benign.csv')
df19 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_idle_benign.csv')
df20 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_interactive_benign.csv')
df21 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_video_benign.csv')
df22 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_webbrowsing_benign.csv')

############### WebOS ############

df23 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/WebOS/Webos_video(live&normal)_benign.csv')




df_results = pd.DataFrame()

# %%
print("df1 -->> {}".format(len(df1)))
print("df2 -->> {}".format(len(df2)))
print("df3 -->> {}".format(len(df3)))
print("df4 -->> {}".format(len(df4)))
print("df5 -->> {}".format(len(df5)))
print("df6 -->> {}".format(len(df6)))
print("df7 -->> {}".format(len(df7)))
print("df32 -->> {}".format(len(df32)))
print("df33 -->> {}".format(len(df33)))
print("df34 -->> {}".format(len(df34)))
print("df35 -->> {}".format(len(df35)))
print("/////////////////////////////////////////////////")

print(" LAPTOP ")


print("df8 -->> {}".format(len(df8)))
print("df9 -->> {}".format(len(df9)))
print("df10 -->> {}".format(len(df10)))
print("df11 -->> {}".format(len(df11)))
print("df12 -->> {}".format(len(df12)))

print(" Raspberry ")


print("df13 -->> {}".format(len(df13)))
print("df14 -->> {}".format(len(df14)))
print("df15 -->> {}".format(len(df15)))
print("df16 -->> {}".format(len(df16)))
print("df17 -->> {}".format(len(df17)))

print(" Server ")

print("df18 -->> {}".format(len(df18)))
print("df19 -->> {}".format(len(df19)))
print("df20 -->> {}".format(len(df20)))
print("df21 -->> {}".format(len(df21)))
print("df22 -->> {}".format(len(df22)))

print(" WebOS ")

print("df23 -->> {}".format(len(df23)))
# Out:
# df1 -->> 43173
# df2 -->> 1213354
# df3 -->> 3621
# df4 -->> 22111
# df5 -->> 14156
# df6 -->> 24476
# df7 -->> 3106
# df32 -->> 18460
# df33 -->> 10285
# df34 -->> 7708
# df35 -->> 234892
# /////////////////////////////////////////////////
#  LAPTOP
# df8 -->> 442866
# df9 -->> 113602
# df10 -->> 81681
# df11 -->> 29010
# df12 -->> 99235
#  Raspberry
# df13 -->> 276808
# df14 -->> 73
# df15 -->> 104241
# df16 -->> 57205
# df17 -->> 123298
#  Server
# df18 -->> 564831
# df19 -->> 13459
# df20 -->> 123728
# df21 -->> 109497
# df22 -->> 43713
#  WebOS
# df23 -->> 177704

# %%
# Prune the datasets for labeling process for malicious data


# For WebOS = 18:56:80:17:d0:ef
index_names = df1[((df1['HW_dst'] != '18:56:80:17:d0:ef') & (df1['Hw_src'] != '18:56:80:17:d0:ef'))].index
df1.drop(index_names, inplace = True)

# Big_Server_Monero_mining_data = a4:bb:6d:ac:e1:fd

index_names = df2[((df2['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df2['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df2.drop(index_names, inplace = True)

# ege_data_rasberry = dc:a6:32:67:66:4b	

index_names = df3[((df3['HW_dst'] != 'dc:a6:32:67:66:4b') & (df3['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df3.drop(index_names, inplace = True)

# Rasberry_binary_monero_mining = dc:a6:32:68:35:8a

index_names = df4[((df4['HW_dst'] != 'dc:a6:32:68:35:8a') & (df4['Hw_src'] != 'dc:a6:32:68:35:8a'))].index
df4.drop(index_names, inplace = True)

# Rasberry_network_data_2 = dc:a6:32:67:66:4b

index_names = df5[((df5['HW_dst'] != 'dc:a6:32:67:66:4b') & (df5['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df5.drop(index_names, inplace = True)

# Rasberry-Webmine = dc:a6:32:67:66:4b
index_names = df6[((df6['HW_dst'] != 'dc:a6:32:67:66:4b') & (df6['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df6.drop(index_names, inplace = True)

# Server_Webmine_Network_data = a4:bb:6d:ac:e1:fd

index_names = df7[((df7['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df7['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df7.drop(index_names, inplace = True)

# Server_%50_Mining = a4:bb:6d:ac:e1:fd

index_names = df32[((df32['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df32['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df32.drop(index_names, inplace = True)

# Rasberry_webmine_%10 = dc:a6:32:67:66:4b

index_names = df33[((df33['HW_dst'] != 'dc:a6:32:67:66:4b') & (df33['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df33.drop(index_names, inplace = True)

# Rasberry_webmine_%50 = dc:a6:32:68:35:8a

index_names = df34[((df34['HW_dst'] != 'dc:a6:32:68:35:8a') & (df34['Hw_src'] != 'dc:a6:32:68:35:8a'))].index
df34.drop(index_names, inplace = True)

# Desktop_Webmine_%100 = dc:a6:32:68:35:8a

index_names = df35[((df35['HW_dst'] != 'd8:3b:bf:8f:ba:ba') & (df35['Hw_src'] != 'd8:3b:bf:8f:ba:ba'))].index
df35.drop(index_names, inplace = True)

# %%
#################################################################
#                                                               #
#      Labeling Features for further calculations               #
#                                                               #
#################################################################

df1.insert(7, "Is_malicious", 1)
df2.insert(7, "Is_malicious", 1)
df3.insert(7, "Is_malicious", 1)
df4.insert(7, "Is_malicious", 1)
df5.insert(7, "Is_malicious", 1)
df6.insert(7, "Is_malicious", 1)
df7.insert(7, "Is_malicious", 1)

# ========================================================

df8.insert(7, "Is_malicious", 0)
df9.insert(7, "Is_malicious", 0)
df10.insert(7, "Is_malicious", 0)
df11.insert(7, "Is_malicious", 0)
df12.insert(7, "Is_malicious", 0)
df13.insert(7, "Is_malicious", 0)
df14.insert(7, "Is_malicious", 0)
df15.insert(7, "Is_malicious", 0)
df16.insert(7, "Is_malicious", 0)
df17.insert(7, "Is_malicious", 0)
df18.insert(7, "Is_malicious", 0)
df19.insert(7, "Is_malicious", 0)
df20.insert(7, "Is_malicious", 0)
df21.insert(7, "Is_malicious", 0)
df22.insert(7, "Is_malicious", 0)
df23.insert(7, "Is_malicious", 0)

# ========================================================


df32.insert(7, "Is_malicious", 1)
df33.insert(7, "Is_malicious", 1)
df34.insert(7, "Is_malicious", 1)
df35.insert(7, "Is_malicious", 1)

# %%
def run_process(a,b,c,d,x):
    #run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)
 
  
    df_malicious_Train = a.copy()
    df_benign_Train    = b.copy()
    
    df_malicious_Test = c.copy()
    df_benign_Test    = d.copy()
    
    
    
    from tsfresh import extract_features, select_features
    from tsfresh.utilities.dataframe_functions import impute
    from tsfresh import extract_features
    from tsfresh.feature_selection.relevance import calculate_relevance_table


    df_malicious_Train.reset_index(drop=True, inplace=True) #reset index
    df_malicious_Train['id']= np.floor(df_malicious_Train.index.array/10)
    
    df_malicious_Test.reset_index(drop=True, inplace=True) #reset index
    df_malicious_Test['id']= np.floor(df_malicious_Test.index.array/10)
    
    
    df_benign_Train.reset_index(drop=True, inplace=True) #reset index
    df_benign_Train['id']= np.floor(df_benign_Train.index.array/10)
    
    df_benign_Test.reset_index(drop=True, inplace=True) #reset index
    df_benign_Test['id']= np.floor(df_benign_Test.index.array/10)
    


    tf1=tsfresh.extract_features(df_malicious_Train,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf1['class']= 1
    
    tf1_1=tsfresh.extract_features(df_malicious_Test,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf1_1['class']= 1

      
    tf2=tsfresh.extract_features(df_benign_Train,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf2['class']= 0
    
    tf2_1=tsfresh.extract_features(df_benign_Test,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf2_1['class']= 0
    

    tf2.columns = tf1.columns
    tf2_1.columns = tf1_1.columns
    

    features_train=pd.concat([tf1,tf2])
    features_test=pd.concat([tf1_1,tf2_1])
    
    
    features2_train = features_train.copy()
    features2_train.reset_index(drop=True, inplace=True)
    

    
    y_train = pd.Series(data = features2_train['class'], index=features2_train.index)
    
    relevance_table_train = calculate_relevance_table(features2_train, y_train)
    

    relevance_table_train = relevance_table_train[relevance_table_train.relevant]
    relevance_table_train.sort_values("p_value", inplace=True)
    best_features_train = relevance_table_train[relevance_table_train['p_value'] <= 0.05] 
    
    
    df_ML_train = pd.DataFrame()
    df_ML_test  = pd.DataFrame()
    

    df_ML_train[best_features_train.feature] = features_train[best_features_train.feature]

    df_ML_test[best_features_train.feature] = features_test[best_features_train.feature]


    final = ML_Process(df_ML_train,df_ML_test,x)
    
    return final

# %%
def ML_Process(df_ML_train,df_ML_test,x):
    df_results = x.copy() 
    print('let the ml starts')
  
    from sklearn import neighbors, metrics
    from sklearn.preprocessing import LabelEncoder
    

    X_train = df_ML_train.drop('class',axis=1).to_numpy()
    y_train = df_ML_train['class'].to_numpy()

    X_test = df_ML_test.drop('class',axis=1).to_numpy()
    y_test = df_ML_test['class'].to_numpy()

    
    from sklearn.model_selection import train_test_split
    Le = LabelEncoder()
    for i in range(len(X_train[0])):
        X_train[:, i] = Le.fit_transform(X_train[:, i])
    for i in range(len(X_train[0])):
        X_test[:, i] = Le.fit_transform(X_test[:, i])


    #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=8675309)

    
    from sklearn.linear_model import LogisticRegression
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.svm import SVC
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.naive_bayes import GaussianNB
    #from xgboost import XGBClassifier
    from sklearn import model_selection
    from sklearn.utils import class_weight
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    import numpy as np
    import pandas as pd
    y_train = y_train.ravel()
    dfs = []
    models = [
          ('LogReg', LogisticRegression()), 
          #('RF', RandomForestClassifier()),
          ('KNN', KNeighborsClassifier()),
          ('SVM', SVC()), 
          ('GNB', GaussianNB())
          #('XGB', XGBClassifier())
            ]
    results = []
    names = []
    scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
    target_names = ['malignant', 'benign']
    for name, model in models:
        kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
        cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, 
                                                    scoring=scoring)

        clf = model.fit(X_train, y_train)

        y_pred = clf.predict(X_test)
        print(name)
        print(classification_report(y_test, y_pred, target_names=target_names))
        results.append(cv_results)
        names.append(name)
        this_df = pd.DataFrame(cv_results)
        this_df['model'] = name
        dfs.append(this_df)
        df_resulta = df_results.append(dfs)
        final = pd.concat(dfs, ignore_index=True)
        print(final)


    return(final)

# %%
## Train: Webmine, Test: WebminePool
 
df_malicious_Train = pd.concat([df5])
df_malicious_Test = pd.concat([df6])


df_benign_Train = pd.concat([df13,df14,df15,df16,df17])[:450000]
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])[450000:]

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")


print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)
 
end = timer()
print(end - start)
# Out:
# malicious_train: 12871
# malicious_test: 19643
# benign_train: 450000
# benign_test: 111625
# After droppping NAN rows:
# malicious_train: 12871
# malicious_test: 19643
# benign_train: 450000
# benign_test: 111625
# Feature Extraction: 100%|█████████████████████| 144/144 [00:02<00:00, 48.73it/s]
# Feature Extraction: 100%|█████████████████████| 152/152 [00:03<00:00, 38.62it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:05<00:00,  2.45it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:18<00:00,  8.76it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.99      0.98     11163
#       benign       0.92      0.81      0.86      1965
#
#     accuracy                           0.96     13128
#    macro avg       0.95      0.90      0.92     13128
# weighted avg       0.96      0.96      0.96     13128
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0
it_time  score_time  test_accuracy  test_precision_weighted  \
# 0    1.032351    0.023884       0.992979                 0.992775
# 1    1.108005    0.026720       0.992223                 0.991944
# 2    0.846927    0.021305       0.993087                 0.992883
# 3    1.027660    0.021268       0.993410                 0.993221
# 4    1.035879    0.021311       0.992330                 0.992141
# 5    0.072494   13.763048       0.986390                 0.985475
# 6    0.060058   13.312601       0.985310                 0.984344
# 7    0.060759   13.490714       0.987254                 0.986374
# 8    0.060975   13.630177       0.985308                 0.984434
# 9    0.063286   13.943345       0.987253                 0.986448
# 10  13.890523    9.130271       0.987578                 0.987007
# 11  14.499660    9.273320       0.987470                 0.986739
# 12  14.051334    9.344368       0.987902                 0.987270
# 13  14.868187    9.345928       0.987901                 0.987117
# 14  14.548804    9.235632       0.988765                 0.988092
# 15   0.201739    0.053596       0.999568                 0.999568
# 16   0.196661    0.051596       0.999352                 0.999352
# 17   0.201228    0.053146       0.999352                 0.999352
# 18   0.199077    0.054044       0.999244                 0.999244
# 19   0.200549    0.054707       0.999676                 0.999676
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.992979          0.992815      0.992410  LogReg
# 1               0.992223          0.992001      0.981768  LogReg
# 2               0.993087          0.992789      0.990833  LogReg
# 3               0.993410          0.993261      0.990344  LogReg
# 4               0.992330          0.992213      0.984112  LogReg
# 5               0.986390          0.985634      0.955271     KNN
# 6               0.985310          0.984662      0.934438     KNN
# 7               0.987254          0.986246      0.948531     KNN
# 8               0.985308          0.984740      0.947253     KNN
# 9               0.987253          0.986673      0.947472     KNN
# 10              0.987578          0.986399      0.923347     SVM
# 11              0.987470          0.986217      0.917140     SVM
# 12              0.987902          0.986754      0.925785     SVM
# 13              0.987901          0.987036      0.915624     SVM
# 14              0.988765          0.987885      0.933666     SVM
# 15              0.999568          0.999566      1.000000     GNB
# 16              0.999352          0.999348      0.996047     GNB
# 17              0.999352          0.999348      1.000000     GNB
# 18              0.999244          0.999239      1.000000     GNB
# 19              0.999676          0.999675      0.997967     GNB
# 411.2405991100004

# %%
## Train: WebminePool, Test: Webmine
 
df_malicious_Train = pd.concat([df6])
df_malicious_Test = pd.concat([df5])


df_benign_Train = pd.concat([df13,df14,df15,df16,df17])[:450000]
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])[450000:]

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")


print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)
 
end = timer()
print(end - start)
# Out:
# malicious_train: 19643
# malicious_test: 12871
# benign_train: 450000
# benign_test: 111625
# After droppping NAN rows:
# malicious_train: 19643
# malicious_test: 12871
# benign_train: 450000
# benign_test: 111625
# Feature Extraction: 100%|█████████████████████| 152/152 [00:03<00:00, 38.83it/s]
# Feature Extraction: 100%|█████████████████████| 144/144 [00:02<00:00, 55.50it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:04<00:00,  2.50it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:17<00:00,  9.05it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.98      0.98     11163
#       benign       0.82      0.85      0.83      1288
#
#     accuracy                           0.97     12451
#    macro avg       0.90      0.91      0.91     12451
# weighted avg       0.97      0.97      0.97     12451
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.059858    0.022082       0.991589                 0.991401
# 1  1.116981    0.021914       0.992441                 0.992275
# 2  1.090642    0.021538       0.991696                 0.991504
# 3  1.115772    0.021677       0.991802                 0.991625
# 4  1.106091    0.021537       0.991057                 0.990843
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.991589          0.991439      0.992651  LogReg
# 1              0.992441          0.992248      0.995495  LogReg
# 2              0.991696          0.991530      0.990672  LogReg
# 3              0.991802          0.991540      0.995289  LogReg
# 4              0.991057          0.990896      0.992284  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.94      0.95     11163
#       benign       0.57      0.71      0.63      1288
#
#     accuracy                           0.91     12451
#    macro avg       0.77      0.82      0.79     12451
# weighted avg       0.92      0.91      0.92     12451
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.059858    0.022082       0.991589                 0.991401
# 1  1.116981    0.021914       0.992441                 0.992275
# 2  1.090642    0.021538       0.991696                 0.991504
# 3  1.115772    0.021677       0.991802                 0.991625
# 4  1.106091    0.021537       0.991057                 0.990843
# 5  0.091391   14.013949       0.982221                 0.981293
# 6  0.069166   14.513196       0.981263                 0.980386
# 7  0.068184   14.355649       0.979559                 0.978249
# 8  0.068525   14.489534       0.980411                 0.979494
# 9  0.068572   14.530381       0.980304                 0.979746
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.991589          0.991439      0.992651  LogReg
# 1              0.992441          0.992248      0.995495  LogReg
# 2              0.991696          0.991530      0.990672  LogReg
# 3              0.991802          0.991540      0.995289  LogReg
# 4              0.991057          0.990896      0.992284  LogReg
# 5              0.982221          0.981521      0.959477     KNN
# 6              0.981263          0.980693      0.958469     KNN
# 7              0.979559          0.978559      0.935885     KNN
# 8              0.980411          0.979824      0.954742     KNN
# 9              0.980304          0.979989      0.963215     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       1.00      0.65      0.79     11163
#       benign       0.25      0.98      0.39      1288
#
#     accuracy                           0.69     12451
#    macro avg       0.62      0.82      0.59     12451
# weighted avg       0.92      0.69      0.75     12451
#
#      fit_time  score_time  test_accuracy  test_precision_weighted  \
# 
# 17              0.999042          0.999044      0.998414     GNB
# 18              0.999042          0.999047      0.999556     GNB
# 19              0.998935          0.998938      0.999608     GNB
# 453.5430011240005

# %%
## Train: Raspberry (server), Test: binary (WebOS)
 
df_malicious_Train = pd.concat([df4])
df_malicious_Test = pd.concat([df1])


df_benign_Train = pd.concat([df14,df15,df16,df17])
df_benign_Test = pd.concat([df14,df15,df16,df17])

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)
 
end = timer()
print(end - start)
# Out:
# malicious_train: 11745
# malicious_test: 41572
# benign_train: 284817
# benign_test: 284817
# After droppping NAN rows:
# malicious_train: 11745
# malicious_test: 41572
# benign_train: 284817
# benign_test: 284817
# Feature Extraction: 100%|█████████████████████| 147/147 [00:02<00:00, 59.63it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:08<00:00, 19.93it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:41<00:00,  3.89it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:41<00:00,  3.83it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.88      1.00      0.93     28482
#       benign       0.57      0.02      0.05      4158
#
#     accuracy                           0.87     32640
#    macro avg       0.72      0.51      0.49     32640
# weighted avg       0.84      0.87      0.82     32640
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.670878    0.016850       0.995448                 0.995507
# 1  0.689840    0.015579       0.995954                 0.995939
# 2  0.664199    0.015765       0.994773                 0.994881
# 3  0.642392    0.015523       0.995448                 0.995504
# 4  0.653812    0.015522       0.996291                 0.996291
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.995448          0.995473      0.999135  LogReg
# 1              0.995954          0.995946      0.998848  LogReg
# 2              0.994773          0.994815      0.998983  LogReg
# 3              0.995448          0.995471      0.999215  LogReg
# 4              0.996291          0.996291      0.999594  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.88      1.00      0.93     28482
#       benign       0.72      0.03      0.05      4158
#
#     accuracy                           0.87     32640
#    macro avg       0.80      0.51      0.49     32640
# weighted avg       0.86      0.87      0.82     32640
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.670878    0.016850       0.995448                 0.995507
# 1  0.689840    0.015579       0.995954                 0.995939
# 2  0.664199    0.015765       0.994773                 0.994881
# 3  0.642392    0.015523       0.995448                 0.995504
# 4  0.653812    0.015522       0.996291                 0.996291
# 5  0.058219    5.663634       0.992077                 0.992456
# 6  0.044289    5.645517       0.991571                 0.991812
# 7  0.044602    5.552185       0.987692                 0.988020
# 8  0.044366    5.773202       0.991570                 0.991687
# 9  0.044281    5.728148       0.991401                 0.991692
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.995448          0.995473      0.999135  LogReg
# 1               0.995954          0.995946      0.998848  LogReg
# 2               0.994773          0.994815      0.998983  LogReg
# 3               0.995448          0.995471      0.999215  LogReg
# 4               0.996291          0.996291      0.999594  LogReg
# 5               0.992077          0.992218      0.982661     KNN
# 6               0.991571          0.991669      0.984087     KNN
# 7               0.987692          0.987833      0.978624     KNN
# 8               0.991570          0.991622      0.980887     KNN
# 9               0.991401          0.991519      0.991423     KNN
# 10              0.990560          0.990343      0.996834     SVM
# 11              0.988200          0.987850      0.996591     SVM
# 12              0.983645          0.982844      0.996078     SVM
# 13              0.989209          0.988895      0.996760     SVM
# 14              0.990221          0.990112      0.997096     SVM
# 15              1.000000          1.000000      1.000000     GNB
# 16              1.000000          1.000000      1.000000     GNB
# 17              1.000000          1.000000      1.000000     GNB
# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 325.581138775

# %%
## Train: Binary (raspberry), Test: in-browser (aggressive) (raspberry)
 
df_malicious_Train = pd.concat([df4])
df_malicious_Test = pd.concat([df6])

df_benign_Train = pd.concat([df13,df14,df15,df16,df17])[:450000]
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])[450000:]

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)
 
end = timer()
print(end - start)
# Out:
# malicious_train: 11745
# malicious_test: 19643
# benign_train: 450000
# benign_test: 111625
# After droppping NAN rows:
# malicious_train: 11745
# malicious_test: 19643
# benign_train: 450000
# benign_test: 111625
# Feature Extraction: 100%|█████████████████████| 147/147 [00:03<00:00, 46.21it/s]
# Feature Extraction: 100%|█████████████████████| 152/152 [00:04<00:00, 35.07it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:03<00:00,  2.51it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:17<00:00,  9.03it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.88      1.00      0.93     11163
#       benign       0.98      0.19      0.32      1965
#
#     accuracy                           0.88     13128
#    macro avg       0.93      0.60      0.63     13128
# weighted avg       0.89      0.88      0.84     13128
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.020993    0.021719       0.997943                 0.997928
# 1  1.047020    0.021428       0.997076                 0.997215
# 2  1.078097    0.021150       0.998159                 0.998156
# 3  1.093040    0.021149       0.996968                 0.997052
# 4  1.070723    0.021180       0.998592                 0.998603
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0
it_time  score_time  test_accuracy  test_precision_weighted  \
# 0    1.020993    0.021719       0.997943                 0.997928
# 1    1.047020    0.021428       0.997076                 0.997215
# 2    1.078097    0.021150       0.998159                 0.998156
# 3    1.093040    0.021149       0.996968                 0.997052
# 4    1.070723    0.021180       0.998592                 0.998603
# 5    0.090640   13.968492       0.994911                 0.995069
# 6    0.069077   13.767529       0.995560                 0.995661
# 7    0.069181   13.971035       0.994153                 0.994293
# 8    0.068907   14.418993       0.994586                 0.994883
# 9    0.068923   14.039680       0.993395                 0.993640
# 10  11.114666    7.101947       0.993611                 0.993736
# 11  11.253904    7.191035       0.993286                 0.993723
# 12  11.264299    7.218518       0.995777                 0.995849
# 13  11.357219    7.070672       0.992095                 0.992511
# 14  11.331483    7.122416       0.994261                 0.994516
# 15   0.218139    0.061033       1.000000                 1.000000
# 16   0.212913    0.053934       1.000000                 1.000000
# 17   0.212575    0.053856       1.000000                 1.000000
# 18   0.212381    0.054008       1.000000                 1.000000
# 19   0.212418    0.053848       1.000000                 1.000000
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.997943          0.997933      0.999814  LogReg
# 1               0.997076          0.997121      0.999321  LogReg
# 2               0.998159          0.998157      0.999597  LogReg
# 3               0.996968          0.996999      0.999570  LogReg
# 4               0.998592          0.998597      0.999867  LogReg
# 5               0.994911          0.994973      0.991176     KNN
# 6               0.995560          0.995602      0.988139     KNN
# 7               0.994153          0.994213      0.983898     KNN
# 8               0.994586          0.994695      0.990281     KNN
# 9               0.993395          0.993495      0.990249     KNN
# 10              0.993611          0.993666      0.998595     SVM
# 11              0.993286          0.993449      0.998365     SVM
# 12              0.995777          0.995807      0.998916     SVM
# 13              0.992095          0.992262      0.997925     SVM
# 14              0.994261          0.994360      0.998921     SVM
# 15              1.000000          1.000000      1.000000     GNB
# 16              1.000000          1.000000      1.000000     GNB
# 17              1.000000          1.000000      1.000000     GNB
# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 384.0026929760006

# %%
## Train: Binary  (raspberry), Test: in-browser (robust)  (raspberry)
  
df_malicious_Train = pd.concat([df4])
df_malicious_Test = pd.concat([df3])

df_benign_Train = pd.concat([df13,df14,df15,df16,df17])
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 699.7130570959998

# %%
## Train: Binary, Test: in-browser (stealthy)
 
df_malicious_Train = pd.concat([df4])
df_malicious_Test = pd.concat([df33])


df_benign_Train = pd.concat([df13,df14,df15,df16,df17])
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)

end = timer()
print(end - start)
# Out:
# malicious_train: 11745
# malicious_test: 9880
# benign_train: 561625
# benign_test: 561625
# After droppping NAN rows:
# malicious_train: 11745
# malicious_test: 9880
# benign_train: 561625
# benign_test: 561625
# Feature Extraction: 100%|█████████████████████| 147/147 [00:02<00:00, 55.61it/s]
# Feature Extraction: 100%|█████████████████████| 142/142 [00:02<00:00, 67.38it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:20<00:00,  1.99it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:21<00:00,  1.95it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.99      1.00      0.99     56163
#       benign       0.88      0.45      0.59       988
#
#     accuracy                           0.99     57151
#    macro avg       0.94      0.72      0.79     57151
# weighted avg       0.99      0.99      0.99     57151
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.287373    0.026509       0.997907                 0.997938
# 1  1.352373    0.025498       0.997384                 0.997352
# 2  1.288956    0.027089       0.997646                 0.997689
# 3  1.306785    0.030216       0.996512                 0.996601
# 4  1.334100    0.025155       0.998692                 0.998695
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.997907          0.997920      0.999684  LogReg
# 1              0.997384          0.997362      0.999594  LogReg
# 2              0.997646          0.997663      0.999734  LogReg
# 3              0.996512          0.996548      0.999050  LogReg
# 4              0.998692          0.998693      0.999825  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.98      1.00      0.99     56163
#       benign       0.58      0.13      0.21       988
#
#     accuracy                           0.98     57151
#    macro avg       0.78      0.56      0.60     57151
# weighted avg       0.98      0.98      0.98     57151
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.287373    0.026509       0.997907                 0.997938
# 1  1.352373    0.025498       0.997384                 0.997352
# 2  1.288956    0.027089       0.997646                 0.997689
# 3  1.306785    0.030216       0.996512                 0.996601
# 4  1.334100    0.025155       0.998692                 0.998695
# 5  0.082935   20.927298       0.995204                 0.995302
# 6  0.080564   21.571925       0.995640                 0.995678
# 7  0.081810   21.528514       0.995291                 0.995434
# 8  0.081178   20.896280       0.994157                 0.994309
# 9  0.082086   21.515686       0.994070                 0.994096
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.997907          0.997920      0.999684  LogReg
# 1               0.997384          0.997362      0.999594  LogReg
# 2               0.997646          0.997663      0.999734  LogReg
# 3               0.996512          0.996548      0.999050  LogReg
# 4               0.998692          0.998693      0.999825  LogReg
# 5               0.995204          0.995247      0.986725     KNN
# 6               0.995640          0.995658      0.982532     KNN
# 7               0.995291          0.995351      0.983577     KNN
# 8               0.994157          0.994223      0.983750     KNN
# 9               0.994070          0.994082      0.979532     KNN
# 10              0.993373          0.993097      0.998102     SVM
# 11              0.993460          0.993240      0.998274     SVM
# 12              0.994245          0.994128      0.998183     SVM
# 13              0.993896          0.993830      0.997540     SVM
# 14              0.995204          0.995125      0.998417     SVM
# 15              1.000000          1.000000      1.000000     GNB
# 16              1.000000          1.000000      1.000000     GNB
# 17              1.000000          1.000000      1.000000     GNB
# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 703.5650659849998

# %%
## Train: in-browser (aggressive), Test: in-browser (stealthy)
 
df_malicious_Train = pd.concat([df5])
df_malicious_Test = pd.concat([df33])


df_benign_Train = pd.concat([df13,df14,df15,df16,df17])
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)

end = timer()
print(end - start)
# Out:
# malicious_train: 12871
# malicious_test: 9880
# benign_train: 561625
# benign_test: 561625
# After droppping NAN rows:
# malicious_train: 12871
# malicious_test: 9880
# benign_train: 561625
# benign_test: 561625
# Feature Extraction: 100%|█████████████████████| 144/144 [00:03<00:00, 43.05it/s]
# Feature Extraction: 100%|█████████████████████| 142/142 [00:02<00:00, 68.91it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:19<00:00,  2.01it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [01:20<00:00,  1.98it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       1.00      1.00      1.00     56163
#       benign       0.88      0.72      0.79       988
#
#     accuracy                           0.99     57151
#    macro avg       0.94      0.86      0.89     57151
# weighted avg       0.99      0.99      0.99     57151
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.067142    0.025759       0.992690                 0.992365
# 1  1.065518    0.025086       0.993037                 0.992786
# 2  1.354021    0.025290       0.993734                 0.993513
# 3  1.038317    0.025166       0.993473                 0.993209
# 4  1.177782    0.025202       0.993647                 0.993420
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0
it_time  score_time  test_accuracy  test_precision_weighted  \
# 0    1.067142    0.025759       0.992690                 0.992365
# 1    1.065518    0.025086       0.993037                 0.992786
# 2    1.354021    0.025290       0.993734                 0.993513
# 3    1.038317    0.025166       0.993473                 0.993209
# 4    1.177782    0.025202       0.993647                 0.993420
# 5    0.083230   21.559979       0.986946                 0.985756
# 6    0.079665   20.620398       0.986510                 0.985176
# 7    0.079589   20.999211       0.988425                 0.987418
# 8    0.080179   21.621862       0.987728                 0.986705
# 9    0.079423   20.812693       0.987119                 0.985846
# 10  19.531325   11.232444       0.988861                 0.988563
# 11  19.331001   11.228837       0.987903                 0.987565
# 12  19.986226   11.215172       0.988686                 0.988338
# 13  19.438970   11.148853       0.988860                 0.988477
# 14  19.558782   11.308556       0.989643                 0.989100
# 15   0.262566    0.074279       0.998956                 0.998957
# 16   0.259003    0.072757       0.999217                 0.999217
# 17   0.265922    0.072625       0.999826                 0.999826
# 18   0.258967    0.072964       0.999217                 0.999217
# 19   0.258928    0.072905       0.998869                 0.998870
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.992690          0.992366      0.983442  LogReg
# 1               0.993037          0.992851      0.985584  LogReg
# 2               0.993734          0.993567      0.990189  LogReg
# 3               0.993473          0.993194      0.988586  LogReg
# 4               0.993647          0.993480      0.982865  LogReg
# 5               0.986946          0.985973      0.924755     KNN
# 6               0.986510          0.985092      0.917734     KNN
# 7               0.988425          0.987463      0.915861     KNN
# 8               0.987728          0.986945      0.930298     KNN
# 9               0.987119          0.986106      0.920124     KNN
# 10              0.988861          0.987329      0.908273     SVM
# 11              0.987903          0.986067      0.917491     SVM
# 12              0.988686          0.986986      0.892342     SVM
# 13              0.988860          0.987293      0.909611     SVM
# 14              0.989643          0.988394      0.921479     SVM
# 15              0.998956          0.998944      1.000000     GNB
# 16              0.999217          0.999210      0.996283     GNB
# 17              0.999826          0.999826      1.000000     GNB
# 18              0.999217          0.999210      1.000000     GNB
# 19              0.998869          0.998854      0.997967     GNB
# 734.9613477069997

# %%
## Train: in-browser (aggressive), Test: in-browser (robust)
 
df_malicious_Train = pd.concat([df4])
df_malicious_Test = pd.concat([df32])


df_benign_Train = pd.concat([df13,df14,df15,df16,df17])
df_benign_Test = pd.concat([df13,df14,df15,df16,df17])

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

#print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
#print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious_Test = df_malicious_Test.dropna()
df_malicious_Train = df_malicious_Train.dropna()

df_benign_Test = df_benign_Test.dropna()
df_benign_Train = df_benign_Train.dropna()

print("After droppping NAN rows: ")

print("malicious_train: {}".format(len(df_malicious_Train)))
print("malicious_test: {}".format(len(df_malicious_Test)))

print("benign_train: {}".format(len(df_benign_Train)))
print("benign_test: {}".format(len(df_benign_Test)))

start = timer()

results_all_combined_s0 = run_process(df_malicious_Train,df_benign_Train,df_malicious_Test,df_benign_Test,df_results)

end = timer()
