# %%
import pandas as pd
import tsfresh
import os
import json
import scapy
import numpy as np
import warnings

from scapy.all import *

warnings.filterwarnings("ignore") #ignore warnings caused by 


#################################################################
#                                                               #
#               malicious csv files import                      #
#                                                               #
#################################################################

df1 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/WebOS_binary.csv') #
df2 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_Binary.csv') #
df3 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Webmine_Robust.csv')
df4 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Binary.csv') #
df5 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_Webmine_Aggressive.csv')
df6 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Aggressive.csv')
df7 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_WebminePool_Aggressive.csv') #

df32 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Server_WebminePool_Robust.csv') #
df33 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Stealthy.csv') #
df34 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Raspberry_WebminePool_Robust.csv') #
df35 = pd.read_csv('/home/csl/Desktop/ege/new_captures/malicious/Desktop_WebminePool_Aggressive.csv') #


#################################################################
#                                                               #
#               benign csv files import                         #
#                                                               #
#################################################################

############### LAPTOP #############

df8 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_download_benign.csv')
df9 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_idle_benign.csv')
df10 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_interactive_benign.csv')
df11 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_video_benign.csv')
df12 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Laptop/Laptop_webbrowsing_benign.csv')

############### Raspberry ##########

df13 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_download_benign.csv')
df14 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_idle_benign.csv')
df15 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_interactive_benign.csv')
df16 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_video_benign.csv')
df17 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Raspberry/Raspberry_webbrowsing_benign.csv')

############### Server ############


df18 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_download_benign.csv')
df19 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_idle_benign.csv')
df20 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_interactive_benign.csv')
df21 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_video_benign.csv')
df22 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/Server/Server_webbrowsing_benign.csv')

############### WebOS ############

df23 = pd.read_csv('/home/csl/Desktop/ege/new_captures/benign-2/WebOS/Webos_video(live&normal)_benign.csv')




df_results = pd.DataFrame()

# %%
print("df1 -->> {}".format(len(df1)))
print("df2 -->> {}".format(len(df2)))
print("df3 -->> {}".format(len(df3)))
print("df4 -->> {}".format(len(df4)))
print("df5 -->> {}".format(len(df5)))
print("df6 -->> {}".format(len(df6)))
print("df7 -->> {}".format(len(df7)))
print("df32 -->> {}".format(len(df32)))
print("df33 -->> {}".format(len(df33)))
print("df34 -->> {}".format(len(df34)))
print("df35 -->> {}".format(len(df35)))
print("/////////////////////////////////////////////////")

print(" LAPTOP ")


print("df8 -->> {}".format(len(df8)))
print("df9 -->> {}".format(len(df9)))
print("df10 -->> {}".format(len(df10)))
print("df11 -->> {}".format(len(df11)))
print("df12 -->> {}".format(len(df12)))

print(" Raspberry ")


print("df13 -->> {}".format(len(df13)))
print("df14 -->> {}".format(len(df14)))
print("df15 -->> {}".format(len(df15)))
print("df16 -->> {}".format(len(df16)))
print("df17 -->> {}".format(len(df17)))

print(" Server ")

print("df18 -->> {}".format(len(df18)))
print("df19 -->> {}".format(len(df19)))
print("df20 -->> {}".format(len(df20)))
print("df21 -->> {}".format(len(df21)))
print("df22 -->> {}".format(len(df22)))

print(" WebOS ")

print("df23 -->> {}".format(len(df23)))


df_malicious = pd.concat([df1,df2,df3,df4,df5,df6,df7,df32,df33,df34,df35])
 
df_benign = pd.concat([df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))
# Out:
# df1 -->> 43173
# df2 -->> 1213354
# df3 -->> 3621
# df4 -->> 22111
# df5 -->> 14156
# df6 -->> 24476
# df7 -->> 3106
# df32 -->> 18460
# df33 -->> 10285
# df34 -->> 7708
# df35 -->> 234892
# /////////////////////////////////////////////////
#  LAPTOP
# df8 -->> 442866
# df9 -->> 113602
# df10 -->> 81681
# df11 -->> 29010
# df12 -->> 99235
#  Raspberry
# df13 -->> 276808
# df14 -->> 73
# df15 -->> 104241
# df16 -->> 57205
# df17 -->> 123298
#  Server
# df18 -->> 564831
# df19 -->> 13459
# df20 -->> 123728
# df21 -->> 109497
# df22 -->> 43713
#  WebOS
# df23 -->> 177704
# malicious: 1595342
# benign: 2360951

# %%
# Prune the datasets for labeling process for malicious data


# For WebOS = 18:56:80:17:d0:ef
index_names = df1[((df1['HW_dst'] != '18:56:80:17:d0:ef') & (df1['Hw_src'] != '18:56:80:17:d0:ef'))].index
df1.drop(index_names, inplace = True)

# Big_Server_Monero_mining_data = a4:bb:6d:ac:e1:fd

index_names = df2[((df2['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df2['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df2.drop(index_names, inplace = True)

# ege_data_rasberry = dc:a6:32:67:66:4b	

index_names = df3[((df3['HW_dst'] != 'dc:a6:32:67:66:4b') & (df3['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df3.drop(index_names, inplace = True)

# Rasberry_binary_monero_mining = dc:a6:32:68:35:8a

index_names = df4[((df4['HW_dst'] != 'dc:a6:32:68:35:8a') & (df4['Hw_src'] != 'dc:a6:32:68:35:8a'))].index
df4.drop(index_names, inplace = True)

# Rasberry_network_data_2 = dc:a6:32:67:66:4b

index_names = df5[((df5['HW_dst'] != 'dc:a6:32:67:66:4b') & (df5['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df5.drop(index_names, inplace = True)

# Rasberry-Webmine = dc:a6:32:67:66:4b
index_names = df6[((df6['HW_dst'] != 'dc:a6:32:67:66:4b') & (df6['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df6.drop(index_names, inplace = True)

# Server_Webmine_Network_data = a4:bb:6d:ac:e1:fd

index_names = df7[((df7['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df7['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df7.drop(index_names, inplace = True)

# Server_%50_Mining = a4:bb:6d:ac:e1:fd

index_names = df32[((df32['HW_dst'] != 'a4:bb:6d:ac:e1:fd') & (df32['Hw_src'] != 'a4:bb:6d:ac:e1:fd'))].index
df32.drop(index_names, inplace = True)

# Rasberry_webmine_%10 = dc:a6:32:67:66:4b

index_names = df33[((df33['HW_dst'] != 'dc:a6:32:67:66:4b') & (df33['Hw_src'] != 'dc:a6:32:67:66:4b'))].index
df33.drop(index_names, inplace = True)

# Rasberry_webmine_%50 = dc:a6:32:68:35:8a

index_names = df34[((df34['HW_dst'] != 'dc:a6:32:68:35:8a') & (df34['Hw_src'] != 'dc:a6:32:68:35:8a'))].index
df34.drop(index_names, inplace = True)

# Desktop_Webmine_%100 = dc:a6:32:68:35:8a

index_names = df35[((df35['HW_dst'] != 'd8:3b:bf:8f:ba:ba') & (df35['Hw_src'] != 'd8:3b:bf:8f:ba:ba'))].index
df35.drop(index_names, inplace = True)

# %%
#################################################################
#                                                               #
#      Labeling Features for further calculations               #
#                                                               #
#################################################################

df1.insert(7, "Is_malicious", 1)
df2.insert(7, "Is_malicious", 1)
df3.insert(7, "Is_malicious", 1)
df4.insert(7, "Is_malicious", 1)
df5.insert(7, "Is_malicious", 1)
df6.insert(7, "Is_malicious", 1)
df7.insert(7, "Is_malicious", 1)

# ========================================================

df8.insert(7, "Is_malicious", 0)
df9.insert(7, "Is_malicious", 0)
df10.insert(7, "Is_malicious", 0)
df11.insert(7, "Is_malicious", 0)
df12.insert(7, "Is_malicious", 0)
df13.insert(7, "Is_malicious", 0)
df14.insert(7, "Is_malicious", 0)
df15.insert(7, "Is_malicious", 0)
df16.insert(7, "Is_malicious", 0)
df17.insert(7, "Is_malicious", 0)
df18.insert(7, "Is_malicious", 0)
df19.insert(7, "Is_malicious", 0)
df20.insert(7, "Is_malicious", 0)
df21.insert(7, "Is_malicious", 0)
df22.insert(7, "Is_malicious", 0)
df23.insert(7, "Is_malicious", 0)

# ========================================================


df32.insert(7, "Is_malicious", 1)
df33.insert(7, "Is_malicious", 1)
df34.insert(7, "Is_malicious", 1)
df35.insert(7, "Is_malicious", 1)

# %%
def run_process(a,b,x):
    
    df_malicious = a.copy()
    df_benign    = b.copy()
    
    from tsfresh import extract_features, select_features
    from tsfresh.utilities.dataframe_functions import impute
    from tsfresh import extract_features
    from tsfresh.feature_selection.relevance import calculate_relevance_table


    df_malicious.reset_index(drop=True, inplace=True) #reset index
    df_malicious['id']= np.floor(df_malicious.index.array/10)
    df_benign.reset_index(drop=True, inplace=True) #reset index
    df_benign['id']= np.floor(df_benign.index.array/10)
    

    tf1=tsfresh.extract_features(df_malicious,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf1['class']= 1


    
    
    tf2=tsfresh.extract_features(df_benign,impute_function=impute, column_kind='Is_malicious',
                                 column_id='id',column_sort="Time",column_value = "Length")
    tf2['class']= 0


    tf2.columns = tf1.columns

    features=pd.concat([tf1,tf2])
    #features.reset_index(drop=True, inplace=True) #reset index
    
#   best_features = pd.read_csv('/home/ege/Desktop/Mining_data/mining/new_captures/features_final.csv')

    features2 = features.copy()
    features2.reset_index(drop=True, inplace=True)
    
    y = pd.Series(data = features2['class'], index=features2.index)
    
    from tsfresh.examples import load_robot_execution_failures
    from tsfresh import extract_features, select_features
    from tsfresh.feature_selection.relevance import calculate_relevance_table

    relevance_table = calculate_relevance_table(features2, y)
    relevance_table = relevance_table[relevance_table.relevant]
    relevance_table.sort_values("p_value", inplace=True)

    relevance_table
    
    best_features = relevance_table[relevance_table['p_value'] <= 0.05]

    df_ML = pd.DataFrame()

    for pkt in best_features:
        df_ML[best_features.feature] = features[best_features.feature]

    final = ML_Process(df_ML,x)
    

    return final

# %%
def ML_Process(df_ML,x):
    df_results = x.copy() 
    print('let the ml starts')
  
    from sklearn import neighbors, metrics
    from sklearn.preprocessing import LabelEncoder

    #X = df_finalized[['Time', 'Length','Protocol']].values
    X = df_ML.drop('class',axis=1).to_numpy()
    #y = df_finalized[['Is_malicious']]
    y = df_ML['class'].to_numpy()



    #print(X,y)
    
    from sklearn.model_selection import train_test_split
    Le = LabelEncoder()
    for i in range(len(X[0])):
        X[:, i] = Le.fit_transform(X[:, i])

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=8675309)

    
    from sklearn.linear_model import LogisticRegression
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.svm import SVC
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.naive_bayes import GaussianNB
    #from xgboost import XGBClassifier
    from sklearn import model_selection
    from sklearn.utils import class_weight
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    import numpy as np
    import pandas as pd
    y_train = y_train.ravel()
    dfs = []
    models = [
          ('LogReg', LogisticRegression()), 
          #('RF', RandomForestClassifier()),
          ('KNN', KNeighborsClassifier()),
          ('SVM', SVC()), 
          ('GNB', GaussianNB())
          #('XGB', XGBClassifier())
            ]
    results = []
    names = []
    scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
    target_names = ['malignant', 'benign']
    for name, model in models:
        kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
        cv_results = model_selection.cross_validate(model, X_train, y_train, cv=kfold, 
                                                    scoring=scoring)

        clf = model.fit(X_train, y_train)

        y_pred = clf.predict(X_test)
        print(name)
        print(classification_report(y_test, y_pred, target_names=target_names))
        results.append(cv_results)
        names.append(name)
        this_df = pd.DataFrame(cv_results)
        this_df['model'] = name
        dfs.append(this_df)
        df_resulta = df_results.append(dfs)
        final = pd.concat(dfs, ignore_index=True)
        print(final)


    return(final)

# %%
from timeit import default_timer as timer

# %%
## S0: All Combined
 
df_malicious = pd.concat([df1,df2,df3,df4,df5,df6,df7,df32,df33,df34,df35])
 
df_benign = pd.concat([df9,df10,df11,df12,df14,df15,df16,df17,df18,df19,df20,df22,df23])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_all_combined_s0 = run_process(df_malicious,df_benign,df_results)
 
end = timer()
print(end - start)
# Out:
# malicious: 1557230
# benign: 1531780
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 1557230
# benign: 1531780
# Feature Extraction: 100%|█████████████████████| 160/160 [04:19<00:00,  1.62s/it]
# Feature Extraction: 100%|█████████████████████| 160/160 [03:52<00:00,  1.45s/it]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.89      0.90      0.90     38265
#       benign       0.90      0.90      0.90     38961
#
#     accuracy                           0.90     77226
#    macro avg       0.90      0.90      0.90     77226
# weighted avg       0.90      0.90      0.90     77226
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.479976    0.126176       0.900140                 0.900193
# 1  5.571456    0.120239       0.899385                 0.899457
# 2  4.923848    0.124085       0.900486                 0.900647
# 3  5.326804    0.135522       0.895824                 0.895867
# 4  5.548442    0.126836       0.899277                 0.899331
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.900140          0.900144      0.964148  LogReg
# 1              0.899385          0.899384      0.962983  LogReg
# 2              0.900486          0.900486      0.963103  LogReg
# 3              0.895824          0.895823      0.961570  LogReg
# 4              0.899277          0.899280      0.961963  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.93      0.95      0.94     38265
#       benign       0.95      0.93      0.94     38961
#
#     accuracy                           0.94     77226
#    macro avg       0.94      0.94      0.94     77226
# weighted avg       0.94      0.94      0.94     77226
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.479976    0.126176       0.900140                 0.900193
# 1  5.571456    0.120239       0.899385                 0.899457
# 2  4.923848    0.124085       0.900486                 0.900647
# 3  5.326804    0.135522       0.895824                 0.895867
# 4  5.548442    0.126836       0.899277                 0.899331
# 5  0.260787  359.716256       0.936743                 0.936962
# 6  0.242399  364.358787       0.937542                 0.937724
# 7  0.276157  377.758561       0.937283                 0.937533
# 8  0.273382  395.585257       0.935146                 0.935278
# 9  0.276288  343.526473       0.935513                 0.935734
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.900140          0.900144      0.964148  LogReg
# 1              0.899385          0.899384      0.962983  LogReg
# 2              0.900486          0.900486      0.963103  LogReg
# 3              0.895824          0.895823      0.961570  LogReg
# 4              0.899277          0.899280      0.961963  LogReg
# 5              0.936743          0.936744      0.974992     KNN
# 6              0.937542          0.937539      0.974242     KNN
# 7              0.937283          0.937282      0.974438     KNN
# 8              0.935146          0.935143      0.973523     KNN
# 9              0.935513          0.935513      0.973270     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.92      0.94      0.93     38265
#       benign       0.94      0.91      0.93     38961
#
#     accuracy                           0.93     77226
#    macro avg       0.93      0.93      0.93     77226
# weighted avg       0.93      0.93      0.93     77226
#
#        fit_time   score_time  test_accuracy  test_precision_weighted  \
# 0      5.479976     0.126176       0.900140                 0.900193
# 1      5.571456     0.120239       0.899385                 0.899457
# 2      4.923848     0.124085       0.900486                 0.900647
# 3      5.326804     0.135522       0.895824                 0.895867
# 4      5.548442     0.126836       0.899277                 0.899331
# 5      0.260787   359.716256       0.936743                 0.936962
# 6      0.242399   364.358787       0.937542                 0.937724
# 7      0.276157   377.758561       0.937283                 0.937533
# 8      0.273382   395.585257       0.935146                 0.935278
# 9      0.276288   343.526473       0.935513                 0.935734
# 10  2684.847271  1477.203529       0.926751                 0.927088
# 11  2810.551592  1165.817323       0.927938                 0.928288
# 12  2435.747637  1213.386386       0.925974                 0.926383
# 13  2500.124014  1197.664308       0.924787                 0.925132
# 14  2514.596860  1142.790350       0.925758                 0.926208
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.900140          0.900144      0.964148  LogReg
# 1               0.899385          0.899384      0.962983  LogReg
# 2               0.900486          0.900486      0.963103  LogReg
# 3               0.895824          0.895823      0.961570  LogReg
# 4               0.899277          0.899280      0.961963  LogReg
# 5               0.936743          0.936744      0.974992     KNN
# 6               0.937542          0.937539      0.974242     KNN
# 7               0.937283          0.937282      0.974438     KNN
# 8               0.935146          0.935143      0.973523     KNN
# 9               0.935513          0.935513      0.973270     KNN
# 10              0.926751          0.926749      0.975911     SVM
# 11              0.927938          0.927929      0.974765     SVM
# 12              0.925974          0.925968      0.975115     SVM
# 13              0.924787          0.924775      0.975340     SVM
# 14              0.925758          0.925752      0.974858     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.86      0.93      0.89     38265
#       benign       0.92      0.85      0.89     38961
#
#     accuracy                           0.89     77226
#    macro avg       0.89      0.89      0.89     77226
# weighted avg       0.89      0.89      0.89     77226
#
#        fit_time   score_time  test_accuracy  test_precision_weighted  \
# 0      5.479976     0.126176       0.900140                 0.900193
# 1      5.571456     0.120239       0.899385                 0.899457
# 2      4.923848     0.124085       0.900486                 0.900647
# 3      5.326804     0.135522       0.895824                 0.895867
# 4      5.548442     0.126836       0.899277                 0.899331
# 5      0.260787   359.716256       0.936743                 0.936962
# 6      0.242399   364.358787       0.937542                 0.937724
# 7      0.276157   377.758561       0.937283                 0.937533
# 8      0.273382   395.585257       0.935146                 0.935278
# 9      0.276288   343.526473       0.935513                 0.935734
# 10  2684.847271  1477.203529       0.926751                 0.927088
# 11  2810.551592  1165.817323       0.927938                 0.928288
# 12  2435.747637  1213.386386       0.925974                 0.926383
# 13  2500.124014  1197.664308       0.924787                 0.925132
# 14  2514.596860  1142.790350       0.925758                 0.926208
# 15     1.032161     0.481313       0.897032                 0.899935
# 16     1.027481     0.472475       0.891011                 0.893198
# 17     1.017423     0.476443       0.887558                 0.889990
# 18     1.023763     0.473155       0.885875                 0.887675
# 19     1.017844     0.474090       0.891637                 0.894152
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.900140          0.900144      0.964148  LogReg
# 1               0.899385          0.899384      0.962983  LogReg
# 2               0.900486          0.900486      0.963103  LogReg
# 3               0.895824          0.895823      0.961570  LogReg
# 4               0.899277          0.899280      0.961963  LogReg
# 5               0.936743          0.936744      0.974992     KNN
# 6               0.937542          0.937539      0.974242     KNN
# 7               0.937283          0.937282      0.974438     KNN
# 8               0.935146          0.935143      0.973523     KNN
# 9               0.935513          0.935513      0.973270     KNN
# 10              0.926751          0.926749      0.975911     SVM
# 11              0.927938          0.927929      0.974765     SVM
# 12              0.925974          0.925968      0.975115     SVM
# 13              0.924787          0.924775      0.975340     SVM
# 14              0.925758          0.925752      0.974858     SVM
# 15              0.897032          0.896902      0.944735     GNB
# 16              0.891011          0.890883      0.931228     GNB
# 17              0.887558          0.887432      0.929331     GNB
# 18              0.885875          0.885754      0.925086     GNB
# 19              0.891637          0.891515      0.938345     GNB
# 28099.391534851005

# %%
#Scenario 1 :Devices
# 1) Server
 
df_malicious = pd.concat([df2,df7,df32])
df_benign = pd.concat([df8,df18,df20,df21])



print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_server_s1 = run_process(df_malicious,df_benign,df_results)

end = timer()
print(end - start)
# Out:
# malicious: 1217322
# benign: 1240922
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 1217322
# benign: 1240922
# Feature Extraction: 100%|█████████████████████| 160/160 [03:15<00:00,  1.22s/it]
# Feature Extraction: 100%|█████████████████████| 160/160 [03:15<00:00,  1.22s/it]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.99      0.98      0.99     31113
#       benign       0.98      0.99      0.99     30344
#
#     accuracy                           0.99     61457
#    macro avg       0.99      0.99      0.99     61457
# weighted avg       0.99      0.99      0.99     61457
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.150766    0.099974       0.986169                 0.986177
# 1  4.738800    0.105874       0.985437                 0.985440
# 2  5.375978    0.132933       0.985654                 0.985664
# 3  4.859238    0.126845       0.986196                 0.986210
# 4  5.152282    0.098456       0.985925                 0.985942
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.986169          0.986169      0.997611  LogReg
# 1              0.985437          0.985437      0.997192  LogReg
# 2              0.985654          0.985654      0.997325  LogReg
# 3              0.986196          0.986197      0.997827  LogReg
# 4              0.985925          0.985925      0.997685  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.99      0.99      0.99     31113
#       benign       0.99      0.99      0.99     30344
#
#     accuracy                           0.99     61457
#    macro avg       0.99      0.99      0.99     61457
# weighted avg       0.99      0.99      0.99     61457
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.150766    0.099974       0.986169                 0.986177
# 1  4.738800    0.105874       0.985437                 0.985440
# 2  5.375978    0.132933       0.985654                 0.985664
# 3  4.859238    0.126845       0.986196                 0.986210
# 4  5.152282    0.098456       0.985925                 0.985942
# 5  0.205457  241.006980       0.988908                 0.988916
# 6  0.186645  256.557452       0.988583                 0.988588
# 7  0.256340  251.576800       0.989125                 0.989144
# 8  0.335410  231.117855       0.989613                 0.989633
# 9  0.210312  264.450552       0.988338                 0.988346
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.986169          0.986169      0.997611  LogReg
# 1              0.985437          0.985437      0.997192  LogReg
# 2              0.985654          0.985654      0.997325  LogReg
# 3              0.986196          0.986197      0.997827  LogReg
# 4              0.985925          0.985925      0.997685  LogReg
# 5              0.988908          0.988908      0.995854     KNN
# 6              0.988583          0.988583      0.995897     KNN
# 7              0.989125          0.989125      0.995420     KNN
# 8              0.989613          0.989614      0.995829     KNN
# 9              0.988338          0.988338      0.995990     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.99      0.99      0.99     31113
#       benign       0.99      0.99      0.99     30344
#
#     accuracy                           0.99     61457
#    macro avg       0.99      0.99      0.99     61457
# weighted avg       0.99      0.99      0.99     61457
#
#       fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0     5.150766    0.099974       0.986169                 0.986177
# 1     4.738800    0.105874       0.985437                 0.985440
# 2     5.375978    0.132933       0.985654                 0.985664
# 3     4.859238    0.126845       0.986196                 0.986210
# 4     5.152282    0.098456       0.985925                 0.985942
# 5     0.205457  241.006980       0.988908                 0.988916
# 6     0.186645  256.557452       0.988583                 0.988588
# 7     0.256340  251.576800       0.989125                 0.989144
# 8     0.335410  231.117855       0.989613                 0.989633
# 9     0.210312  264.450552       0.988338                 0.988346
# 10  339.603648  134.248391       0.987715                 0.987725
# 11  357.039837  133.088827       0.987498                 0.987505
# 12  351.764957  135.291605       0.987471                 0.987475
# 13  373.408714  132.192325       0.987715                 0.987726
# 14  364.024782  138.850534       0.986847                 0.986850
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.986169          0.986169      0.997611  LogReg
# 1               0.985437          0.985437      0.997192  LogReg
# 2               0.985654          0.985654      0.997325  LogReg
# 3               0.986196          0.986197      0.997827  LogReg
# 4               0.985925          0.985925      0.997685  LogReg
# 5               0.988908          0.988908      0.995854     KNN
# 6               0.988583          0.988583      0.995897     KNN
# 7               0.989125          0.989125      0.995420     KNN
# 8               0.989613          0.989614      0.995829     KNN
# 9               0.988338          0.988338      0.995990     KNN
# 10              0.987715          0.987715      0.997995     SVM
# 11              0.987498          0.987498      0.998058     SVM
# 12              0.987471          0.987471      0.998027     SVM
# 13              0.987715          0.987715      0.998423     SVM
# 14              0.986847          0.986847      0.997933     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.99      1.00      0.99     31113
#       benign       1.00      0.99      0.99     30344
#
#     accuracy                           0.99     61457
#    macro avg       0.99      0.99      0.99     61457
# weighted avg       0.99      0.99      0.99     61457
#
#       fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0     5.150766    0.099974       0.986169                 0.986177
# 1     4.738800    0.105874       0.985437                 0.985440
# 2     5.375978    0.132933       0.985654                 0.985664
# 3     4.859238    0.126845       0.986196                 0.986210
# 4     5.152282    0.098456       0.985925                 0.985942
# 5     0.205457  241.006980       0.988908                 0.988916
# 6     0.186645  256.557452       0.988583                 0.988588
# 7     0.256340  251.576800       0.989125                 0.989144
# 8     0.335410  231.117855       0.989613                 0.989633
# 9     0.210312  264.450552       0.988338                 0.988346
# 10  339.603648  134.248391       0.987715                 0.987725
# 11  357.039837  133.088827       0.987498                 0.987505
# 12  351.764957  135.291605       0.987471                 0.987475
# 13  373.408714  132.192325       0.987715                 0.987726
# 14  364.024782  138.850534       0.986847                 0.986850
# 15    0.788422    0.326772       0.993763                 0.993839
# 16    0.781092    0.298607       0.993627                 0.993707
# 17    0.781353    0.303907       0.994468                 0.994526
# 18    0.781465    0.302570       0.994386                 0.994448
# 19    0.781883    0.301642       0.994332                 0.994395
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.986169          0.986169      0.997611  LogReg
# 1               0.985437          0.985437      0.997192  LogReg
# 2               0.985654          0.985654      0.997325  LogReg
# 3               0.986196          0.986197      0.997827  LogReg
# 4               0.985925          0.985925      0.997685  LogReg
# 5               0.988908          0.988908      0.995854     KNN
# 6               0.988583          0.988583      0.995897     KNN
# 7               0.989125          0.989125      0.995420     KNN
# 8               0.989613          0.989614      0.995829     KNN
# 9               0.988338          0.988338      0.995990     KNN
# 10              0.987715          0.987715      0.997995     SVM
# 11              0.987498          0.987498      0.998058     SVM
# 12              0.987471          0.987471      0.998027     SVM
# 13              0.987715          0.987715      0.998423     SVM
# 14              0.986847          0.986847      0.997933     SVM
# 15              0.993763          0.993762      0.998987     GNB
# 16              0.993627          0.993627      0.998830     GNB
# 17              0.994468          0.994467      0.998901     GNB
# 18              0.994386          0.994386      0.999286     GNB
# 19              0.994332          0.994332      0.998852     GNB
# 5462.968332778997

# %%
 #2) Desktop
df_malicious = pd.concat([df35])
df_benign = pd.concat([df10,df9,df22])


print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_Desktop_s1 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 234272
# benign: 238996
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 234272
# benign: 238996
# Feature Extraction: 100%|█████████████████████| 160/160 [00:36<00:00,  4.35it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:37<00:00,  4.26it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.95      0.95      5877
#       benign       0.95      0.95      0.95      5955
#
#     accuracy                           0.95     11832
#    macro avg       0.95      0.95      0.95     11832
# weighted avg       0.95      0.95      0.95     11832
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.967876    0.040622       0.944225                 0.944248
# 1  1.176106    0.038487       0.951683                 0.951690
# 2  1.141330    0.021837       0.953374                 0.953374
# 3  1.061395    0.037603       0.942527                 0.942534
# 4  1.066906    0.021450       0.950556                 0.950562
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.944225          0.944229      0.983334  LogReg
# 1              0.951683          0.951682      0.985271  LogReg
# 2              0.953374          0.953373      0.985021  LogReg
# 3              0.942527          0.942527      0.980544  LogReg
# 4              0.950556          0.950558      0.983831  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.95      0.95      5877
#       benign       0.95      0.95      0.95      5955
#
#     accuracy                           0.95     11832
#    macro avg       0.95      0.95      0.95     11832
# weighted avg       0.95      0.95      0.95     11832
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.967876    0.040622       0.944225                 0.944248
# 1  1.176106    0.038487       0.951683                 0.951690
# 2  1.141330    0.021837       0.953374                 0.953374
# 3  1.061395    0.037603       0.942527                 0.942534
# 4  1.066906    0.021450       0.950556                 0.950562
# 5  0.028629    8.543784       0.937324                 0.937342
# 6  0.027470    8.554302       0.939992                 0.939992
# 7  0.026856    8.687620       0.942668                 0.942683
# 8  0.034798    8.557199       0.938724                 0.938724
# 9  0.039191    8.612802       0.940978                 0.940977
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.944225          0.944229      0.983334  LogReg
# 1              0.951683          0.951682      0.985271  LogReg
# 2              0.953374          0.953373      0.985021  LogReg
# 3              0.942527          0.942527      0.980544  LogReg
# 4              0.950556          0.950558      0.983831  LogReg
# 5              0.937324          0.937328      0.972549     KNN
# 6              0.939992          0.939992      0.975364     KNN
# 7              0.942668          0.942670      0.977205     KNN
# 8              0.938724          0.938724      0.975380     KNN
# 9              0.940978          0.940977      0.974722     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.95      0.95      5877
#       benign       0.95      0.95      0.95      5955
#
#     accuracy                           0.95     11832
#    macro avg       0.95      0.95      0.95     11832
# weighted avg       0.95      0.95      0.95     11832
#
#      fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0    0.967876    0.040622       0.944225                 0.944248
# 1    1.176106    0.038487       0.951683                 0.951690
# 2    1.141330    0.021837       0.953374                 0.953374
# 3    1.061395    0.037603       0.942527                 0.942534
# 4    1.066906    0.021450       0.950556                 0.950562
# 5    0.028629    8.543784       0.937324                 0.937342
# 6    0.027470    8.554302       0.939992                 0.939992
# 7    0.026856    8.687620       0.942668                 0.942683
# 8    0.034798    8.557199       0.938724                 0.938724
# 9    0.039191    8.612802       0.940978                 0.940977
# 10  40.223624   17.682005       0.947042                 0.947267
# 11  40.890869   17.525937       0.951120                 0.951178
# 12  40.463990   17.962501       0.953796                 0.953914
# 13  43.463153   17.532722       0.947035                 0.947132
# 14  41.767426   18.188564       0.952106                 0.952203
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.944225          0.944229      0.983334  LogReg
# 1               0.951683          0.951682      0.985271  LogReg
# 2               0.953374          0.953373      0.985021  LogReg
# 3               0.942527          0.942527      0.980544  LogReg
# 4               0.950556          0.950558      0.983831  LogReg
# 5               0.937324          0.937328      0.972549     KNN
# 6               0.939992          0.939992      0.975364     KNN
# 7               0.942668          0.942670      0.977205     KNN
# 8               0.938724          0.938724      0.975380     KNN
# 9               0.940978          0.940977      0.974722     KNN
# 10              0.947042          0.947052      0.974986     SVM
# 11              0.951120          0.951120      0.975502     SVM
# 12              0.953796          0.953800      0.977029     SVM
# 13              0.947035          0.947033      0.976116     SVM
# 14              0.952106          0.952111      0.977220     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.90      1.00      0.95      5877
#       benign       1.00      0.89      0.94      5955
#
#     accuracy                           0.95     11832
#    macro avg       0.95      0.95      0.95     11832
# weighted avg       0.95      0.95      0.95     11832
#
#      fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0    0.967876    0.040622       0.944225                 0.944248
# 1    1.176106    0.038487       0.951683                 0.951690
# 2    1.141330    0.021837       0.953374                 0.953374
# 3    1.061395    0.037603       0.942527                 0.942534
# 4    1.066906    0.021450       0.950556                 0.950562
# 5    0.028629    8.543784       0.937324                 0.937342
# 6    0.027470    8.554302       0.939992                 0.939992
# 7    0.026856    8.687620       0.942668                 0.942683
# 8    0.034798    8.557199       0.938724                 0.938724
# 9    0.039191    8.612802       0.940978                 0.940977
# 10  40.223624   17.682005       0.947042                 0.947267
# 11  40.890869   17.525937       0.951120                 0.951178
# 12  40.463990   17.962501       0.953796                 0.953914
# 13  43.463153   17.532722       0.947035                 0.947132
# 14  41.767426   18.188564       0.952106                 0.952203
# 15   0.109357    0.044160       0.950423                 0.954784
# 16   0.101093    0.041751       0.941259                 0.947392
# 17   0.099912    0.041290       0.950838                 0.955117
# 18   0.099828    0.043825       0.940837                 0.947088
# 19   0.097258    0.044081       0.948021                 0.952820
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.944225          0.944229      0.983334  LogReg
# 1               0.951683          0.951682      0.985271  LogReg
# 2               0.953374          0.953373      0.985021  LogReg
# 3               0.942527          0.942527      0.980544  LogReg
# 4               0.950556          0.950558      0.983831  LogReg
# 5               0.937324          0.937328      0.972549     KNN
# 6               0.939992          0.939992      0.975364     KNN
# 7               0.942668          0.942670      0.977205     KNN
# 8               0.938724          0.938724      0.975380     KNN
# 9               0.940978          0.940977      0.974722     KNN
# 10              0.947042          0.947052      0.974986     SVM
# 11              0.951120          0.951120      0.975502     SVM
# 12              0.953796          0.953800      0.977029     SVM
# 13              0.947035          0.947033      0.976116     SVM
# 14              0.952106          0.952111      0.977220     SVM
# 15              0.950423          0.950231      0.999710     GNB
# 16              0.941259          0.941029      1.000000     GNB
# 17              0.950838          0.950676      0.999847     GNB
# 18              0.940837          0.940623      1.000000     GNB
# 19              0.948021          0.947820      0.999568     GNB
# 585.2815749959991

# %%
#3) Raspberry
df_malicious = pd.concat([df3,df4,df5,df6,df33,df34])
df_benign = pd.concat([df19,df16])


print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_Raspberry_s1 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 64064
# benign: 70664
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 64064
# benign: 70664
# Feature Extraction: 100%|█████████████████████| 157/157 [00:11<00:00, 13.29it/s]
# Feature Extraction: 100%|█████████████████████| 158/158 [00:12<00:00, 12.16it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.96      0.94      0.95      1751
#       benign       0.93      0.96      0.95      1618
#
#     accuracy                           0.95      3369
#    macro avg       0.95      0.95      0.95      3369
# weighted avg       0.95      0.95      0.95      3369
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.249359    0.010140       0.948046                 0.948043
# 1  0.179861    0.009275       0.949530                 0.949557
# 2  0.217210    0.009446       0.944087                 0.944409
# 3  0.189033    0.009383       0.944087                 0.944628
# 4  0.179208    0.009389       0.948046                 0.948395
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.948046          0.948044      0.988616  LogReg
# 1              0.949530          0.949535      0.988320  LogReg
# 2              0.944087          0.944126      0.984641  LogReg
# 3              0.944087          0.944106      0.984978  LogReg
# 4              0.948046          0.948075      0.989271  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.96      0.92      0.94      1751
#       benign       0.92      0.96      0.94      1618
#
#     accuracy                           0.94      3369
#    macro avg       0.94      0.94      0.94      3369
# weighted avg       0.94      0.94      0.94      3369
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.249359    0.010140       0.948046                 0.948043
# 1  0.179861    0.009275       0.949530                 0.949557
# 2  0.217210    0.009446       0.944087                 0.944409
# 3  0.189033    0.009383       0.944087                 0.944628
# 4  0.179208    0.009389       0.948046                 0.948395
# 5  0.014678    0.682923       0.944582                 0.945257
# 6  0.006931    0.585535       0.940129                 0.940736
# 7  0.006921    0.573815       0.937160                 0.938063
# 8  0.006871    0.572073       0.925779                 0.927049
# 9  0.006768    0.580970       0.937655                 0.939304
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.948046          0.948044      0.988616  LogReg
# 1              0.949530          0.949535      0.988320  LogReg
# 2              0.944087          0.944126      0.984641  LogReg
# 3              0.944087          0.944106      0.984978  LogReg
# 4              0.948046          0.948075      0.989271  LogReg
# 5              0.944582          0.944620      0.979223     KNN
# 6              0.940129          0.940150      0.976690     KNN
# 7              0.937160          0.937226      0.973406     KNN
# 8              0.925779          0.925801      0.974235     KNN
# 9              0.937655          0.937707      0.978418     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.90      0.94      1751
#       benign       0.90      0.97      0.94      1618
#
#     accuracy                           0.94      3369
#    macro avg       0.94      0.94      0.94      3369
# weighted avg       0.94      0.94      0.94      3369
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.249359    0.010140       0.948046                 0.948043
# 1   0.179861    0.009275       0.949530                 0.949557
# 2   0.217210    0.009446       0.944087                 0.944409
# 3   0.189033    0.009383       0.944087                 0.944628
# 4   0.179208    0.009389       0.948046                 0.948395
# 5   0.014678    0.682923       0.944582                 0.945257
# 6   0.006931    0.585535       0.940129                 0.940736
# 7   0.006921    0.573815       0.937160                 0.938063
# 8   0.006871    0.572073       0.925779                 0.927049
# 9   0.006768    0.580970       0.937655                 0.939304
# 10  2.684488    1.871031       0.938149                 0.941244
# 11  2.615160    1.866163       0.938644                 0.940670
# 12  2.602262    1.844017       0.923800                 0.927491
# 13  2.564827    1.828288       0.929243                 0.933297
# 14  2.662157    1.916183       0.933201                 0.937399
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.948046          0.948044      0.988616  LogReg
# 1               0.949530          0.949535      0.988320  LogReg
# 2               0.944087          0.944126      0.984641  LogReg
# 3               0.944087          0.944106      0.984978  LogReg
# 4               0.948046          0.948075      0.989271  LogReg
# 5               0.944582          0.944620      0.979223     KNN
# 6               0.940129          0.940150      0.976690     KNN
# 7               0.937160          0.937226      0.973406     KNN
# 8               0.925779          0.925801      0.974235     KNN
# 9               0.937655          0.937707      0.978418     KNN
# 10              0.938149          0.938189      0.987484     SVM
# 11              0.938644          0.938655      0.985049     SVM
# 12              0.923800          0.923894      0.983384     SVM
# 13              0.929243          0.929210      0.982278     SVM
# 14              0.933201          0.933236      0.988470     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       1.00      1.00      1.00      1751
#       benign       1.00      1.00      1.00      1618
#
#     accuracy                           1.00      3369
#    macro avg       1.00      1.00      1.00      3369
# weighted avg       1.00      1.00      1.00      3369
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.249359    0.010140       0.948046                 0.948043
# 1   0.179861    0.009275       0.949530                 0.949557
# 2   0.217210    0.009446       0.944087                 0.944409
# 3   0.189033    0.009383       0.944087                 0.944628
# 4   0.179208    0.009389       0.948046                 0.948395
# 5   0.014678    0.682923       0.944582                 0.945257
# 6   0.006931    0.585535       0.940129                 0.940736
# 7   0.006921    0.573815       0.937160                 0.938063
# 8   0.006871    0.572073       0.925779                 0.927049
# 9   0.006768    0.580970       0.937655                 0.939304
# 10  2.684488    1.871031       0.938149                 0.941244
# 11  2.615160    1.866163       0.938644                 0.940670
# 12  2.602262    1.844017       0.923800                 0.927491
# 13  2.564827    1.828288       0.929243                 0.933297
# 14  2.662157    1.916183       0.933201                 0.937399
# 15  0.026217    0.015557       1.000000                 1.000000
# 16  0.027264    0.012629       0.999505                 0.999506
# 17  0.026080    0.012630       0.999505                 0.999506
# 18  0.027329    0.016378       1.000000                 1.000000
# 19  0.027382    0.012846       1.000000                 1.000000
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.948046          0.948044      0.988616  LogReg
# 1               0.949530          0.949535      0.988320  LogReg
# 2               0.944087          0.944126      0.984641  LogReg
# 3               0.944087          0.944106      0.984978  LogReg
# 4               0.948046          0.948075      0.989271  LogReg
# 5               0.944582          0.944620      0.979223     KNN
# 6               0.940129          0.940150      0.976690     KNN
# 7               0.937160          0.937226      0.973406     KNN
# 8               0.925779          0.925801      0.974235     KNN
# 9               0.937655          0.937707      0.978418     KNN
# 10              0.938149          0.938189      0.987484     SVM
# 11              0.938644          0.938655      0.985049     SVM
# 12              0.923800          0.923894      0.983384     SVM
# 13              0.929243          0.929210      0.982278     SVM
# 14              0.933201          0.933236      0.988470     SVM
# 15              1.000000          1.000000      1.000000     GNB
# 16              0.999505          0.999505      0.999486     GNB
# 17              0.999505          0.999505      1.000000     GNB
# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 81.84076118899975

# %%
#4) WebOS
df_malicious = pd.concat([df1])
df_benign = pd.concat([df22])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_WebOS_s1 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 41572
# benign: 43713
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 41572
# benign: 43713
# Feature Extraction: 100%|█████████████████████| 160/160 [00:08<00:00, 19.60it/s]
# Feature Extraction: 100%|█████████████████████| 157/157 [00:09<00:00, 16.99it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.81      0.78      0.79      1104
#       benign       0.77      0.80      0.79      1029
#
#     accuracy                           0.79      2133
#    macro avg       0.79      0.79      0.79      2133
# weighted avg       0.79      0.79      0.79      2133
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.192062    0.009525       0.779687                 0.782669
# 1  0.143322    0.009682       0.773438                 0.775966
# 2  0.172829    0.007872       0.777170                 0.777327
# 3  0.146301    0.007861       0.775606                 0.776032
# 4  0.182269    0.007879       0.777952                 0.778136
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.779688          0.779789      0.863680  LogReg
# 1              0.773438          0.773520      0.860444  LogReg
# 2              0.777170          0.777076      0.862830  LogReg
# 3              0.775606          0.775648      0.863141  LogReg
# 4              0.777952          0.777996      0.873789  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.81      0.72      0.76      1104
#       benign       0.73      0.82      0.77      1029
#
#     accuracy                           0.77      2133
#    macro avg       0.77      0.77      0.77      2133
# weighted avg       0.77      0.77      0.77      2133
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.192062    0.009525       0.779687                 0.782669
# 1  0.143322    0.009682       0.773438                 0.775966
# 2  0.172829    0.007872       0.777170                 0.777327
# 3  0.146301    0.007861       0.775606                 0.776032
# 4  0.182269    0.007879       0.777952                 0.778136
# 5  0.009562    0.360740       0.762500                 0.769519
# 6  0.004587    0.338769       0.756250                 0.765050
# 7  0.004702    0.340978       0.742768                 0.744593
# 8  0.004685    0.354037       0.764660                 0.771558
# 9  0.004674    0.327646       0.761532                 0.761472
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.779688          0.779789      0.863680  LogReg
# 1              0.773438          0.773520      0.860444  LogReg
# 2              0.777170          0.777076      0.862830  LogReg
# 3              0.775606          0.775648      0.863141  LogReg
# 4              0.777952          0.777996      0.873789  LogReg
# 5              0.762500          0.762213      0.857779     KNN
# 6              0.756250          0.755599      0.844655     KNN
# 7              0.742768          0.742495      0.835087     KNN
# 8              0.764660          0.763838      0.849157     KNN
# 9              0.761532          0.761446      0.850652     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.84      0.72      0.78      1104
#       benign       0.74      0.86      0.79      1029
#
#     accuracy                           0.78      2133
#    macro avg       0.79      0.79      0.78      2133
# weighted avg       0.79      0.78      0.78      2133
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.192062    0.009525       0.779687                 0.782669
# 1   0.143322    0.009682       0.773438                 0.775966
# 2   0.172829    0.007872       0.777170                 0.777327
# 3   0.146301    0.007861       0.775606                 0.776032
# 4   0.182269    0.007879       0.777952                 0.778136
# 5   0.009562    0.360740       0.762500                 0.769519
# 6   0.004587    0.338769       0.756250                 0.765050
# 7   0.004702    0.340978       0.742768                 0.744593
# 8   0.004685    0.354037       0.764660                 0.771558
# 9   0.004674    0.327646       0.761532                 0.761472
# 10  2.395619    1.983292       0.767188                 0.779115
# 11  2.282563    1.848667       0.764062                 0.775355
# 12  2.234004    1.947520       0.763096                 0.772108
# 13  2.279191    1.879942       0.767005                 0.781323
# 14  2.284344    1.984878       0.779515                 0.781032
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.779688          0.779789      0.863680  LogReg
# 1               0.773438          0.773520      0.860444  LogReg
# 2               0.777170          0.777076      0.862830  LogReg
# 3               0.775606          0.775648      0.863141  LogReg
# 4               0.777952          0.777996      0.873789  LogReg
# 5               0.762500          0.762213      0.857779     KNN
# 6               0.756250          0.755599      0.844655     KNN
# 7               0.742768          0.742495      0.835087     KNN
# 8               0.764660          0.763838      0.849157     KNN
# 9               0.761532          0.761446      0.850652     KNN
# 10              0.767188          0.766299      0.870695     SVM
# 11              0.764062          0.763109      0.850208     SVM
# 12              0.763096          0.761516      0.850631     SVM
# 13              0.767005          0.764968      0.874309     SVM
# 14              0.779515          0.778764      0.875662     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.79      0.59      0.68      1104
#       benign       0.66      0.83      0.73      1029
#
#     accuracy                           0.71      2133
#    macro avg       0.72      0.71      0.71      2133
# weighted avg       0.73      0.71      0.70      2133
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.192062    0.009525       0.779687                 0.782669
# 1   0.143322    0.009682       0.773438                 0.775966
# 2   0.172829    0.007872       0.777170                 0.777327
# 3   0.146301    0.007861       0.775606                 0.776032
# 4   0.182269    0.007879       0.777952                 0.778136
# 5   0.009562    0.360740       0.762500                 0.769519
# 6   0.004587    0.338769       0.756250                 0.765050
# 7   0.004702    0.340978       0.742768                 0.744593
# 8   0.004685    0.354037       0.764660                 0.771558
# 9   0.004674    0.327646       0.761532                 0.761472
# 10  2.395619    1.983292       0.767188                 0.779115
# 11  2.282563    1.848667       0.764062                 0.775355
# 12  2.234004    1.947520       0.763096                 0.772108
# 13  2.279191    1.879942       0.767005                 0.781323
# 14  2.284344    1.984878       0.779515                 0.781032
# 15  0.014660    0.009655       0.684375                 0.706491
# 16  0.014053    0.009157       0.693750                 0.710626
# 17  0.014158    0.009135       0.682565                 0.693551
# 18  0.020566    0.009332       0.698984                 0.722728
# 19  0.013998    0.009141       0.732604                 0.741456
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.779688          0.779789      0.863680  LogReg
# 1               0.773438          0.773520      0.860444  LogReg
# 2               0.777170          0.777076      0.862830  LogReg
# 3               0.775606          0.775648      0.863141  LogReg
# 4               0.777952          0.777996      0.873789  LogReg
# 5               0.762500          0.762213      0.857779     KNN
# 6               0.756250          0.755599      0.844655     KNN
# 7               0.742768          0.742495      0.835087     KNN
# 8               0.764660          0.763838      0.849157     KNN
# 9               0.761532          0.761446      0.850652     KNN
# 10              0.767188          0.766299      0.870695     SVM
# 11              0.764062          0.763109      0.850208     SVM
# 12              0.763096          0.761516      0.850631     SVM
# 13              0.767005          0.764968      0.874309     SVM
# 14              0.779515          0.778764      0.875662     SVM
# 15              0.684375          0.679990      0.726185     GNB
# 16              0.693750          0.690703      0.738958     GNB
# 17              0.682565          0.678872      0.726805     GNB
# 18              0.698984          0.692878      0.731828     GNB
# 19              0.732604          0.728651      0.771623     GNB
# 64.01101683200977

# %%
# Scenario 2; Throttles
    
    # 1) THR: %10

df_malicious = pd.concat([df33])
df_benign = pd.concat([df19])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_THR_10_s2 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 9880
# benign: 13459
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 9880
# benign: 13459
# Feature Extraction: 100%|█████████████████████| 142/142 [00:02<00:00, 61.74it/s]
# Feature Extraction: 100%|█████████████████████| 150/150 [00:03<00:00, 49.20it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.91      0.93      0.92       341
#       benign       0.90      0.86      0.88       243
#
#     accuracy                           0.90       584
#    macro avg       0.90      0.90      0.90       584
# weighted avg       0.90      0.90      0.90       584
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.141255    0.007222       0.900000                 0.902202
# 1  0.097768    0.006573       0.908571                 0.909852
# 2  0.088637    0.006328       0.902857                 0.903807
# 3  0.062705    0.006270       0.902857                 0.902728
# 4  0.072736    0.006500       0.877143                 0.876831
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.900000          0.900495      0.949686  LogReg
# 1              0.908571          0.908114      0.958399  LogReg
# 2              0.902857          0.902585      0.957875  LogReg
# 3              0.902857          0.902763      0.931738  LogReg
# 4              0.877143          0.876920      0.939801  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.91      0.91      0.91       341
#       benign       0.88      0.88      0.88       243
#
#     accuracy                           0.90       584
#    macro avg       0.90      0.90      0.90       584
# weighted avg       0.90      0.90      0.90       584
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.141255    0.007222       0.900000                 0.902202
# 1  0.097768    0.006573       0.908571                 0.909852
# 2  0.088637    0.006328       0.902857                 0.903807
# 3  0.062705    0.006270       0.902857                 0.902728
# 4  0.072736    0.006500       0.877143                 0.876831
# 5  0.002283    0.094809       0.860000                 0.859576
# 6  0.001288    0.047510       0.842857                 0.843254
# 7  0.001328    0.051385       0.842857                 0.842976
# 8  0.001214    0.045099       0.831429                 0.831281
# 9  0.001243    0.042114       0.871429                 0.871000
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.900000          0.900495      0.949686  LogReg
# 1              0.908571          0.908114      0.958399  LogReg
# 2              0.902857          0.902585      0.957875  LogReg
# 3              0.902857          0.902763      0.931738  LogReg
# 4              0.877143          0.876920      0.939801  LogReg
# 5              0.860000          0.859723      0.927297     KNN
# 6              0.842857          0.842993      0.924333     KNN
# 7              0.842857          0.842577      0.912929     KNN
# 8              0.831429          0.831348      0.906404     KNN
# 9              0.871429          0.870851      0.941040     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.86      0.93      0.90       341
#       benign       0.89      0.79      0.84       243
#
#     accuracy                           0.88       584
#    macro avg       0.88      0.86      0.87       584
# weighted avg       0.88      0.88      0.87       584
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.141255    0.007222       0.900000                 0.902202
# 1   0.097768    0.006573       0.908571                 0.909852
# 2   0.088637    0.006328       0.902857                 0.903807
# 3   0.062705    0.006270       0.902857                 0.902728
# 4   0.072736    0.006500       0.877143                 0.876831
# 5   0.002283    0.094809       0.860000                 0.859576
# 6   0.001288    0.047510       0.842857                 0.843254
# 7   0.001328    0.051385       0.842857                 0.842976
# 8   0.001214    0.045099       0.831429                 0.831281
# 9   0.001243    0.042114       0.871429                 0.871000
# 10  0.115915    0.108272       0.894286                 0.894005
# 11  0.111272    0.102832       0.888571                 0.889370
# 12  0.107032    0.103468       0.871429                 0.878045
# 13  0.108003    0.107782       0.897143                 0.897143
# 14  0.106852    0.101732       0.854286                 0.857880
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.900000          0.900495      0.949686  LogReg
# 1               0.908571          0.908114      0.958399  LogReg
# 2               0.902857          0.902585      0.957875  LogReg
# 3               0.902857          0.902763      0.931738  LogReg
# 4               0.877143          0.876920      0.939801  LogReg
# 5               0.860000          0.859723      0.927297     KNN
# 6               0.842857          0.842993      0.924333     KNN
# 7               0.842857          0.842577      0.912929     KNN
# 8               0.831429          0.831348      0.906404     KNN
# 9               0.871429          0.870851      0.941040     KNN
# 10              0.894286          0.893769      0.945891     SVM
# 11              0.888571          0.888071      0.947760     SVM
# 12              0.871429          0.870117      0.939569     SVM
# 13              0.897143          0.897143      0.933916     SVM
# 14              0.854286          0.851310      0.929146     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       1.00      1.00      1.00       341
#       benign       1.00      1.00      1.00       243
#
#     accuracy                           1.00       584
#    macro avg       1.00      1.00      1.00       584
# weighted avg       1.00      1.00      1.00       584
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.141255    0.007222       0.900000                 0.902202
# 1   0.097768    0.006573       0.908571                 0.909852
# 2   0.088637    0.006328       0.902857                 0.903807
# 3   0.062705    0.006270       0.902857                 0.902728
# 4   0.072736    0.006500       0.877143                 0.876831
# 5   0.002283    0.094809       0.860000                 0.859576
# 6   0.001288    0.047510       0.842857                 0.843254
# 7   0.001328    0.051385       0.842857                 0.842976
# 8   0.001214    0.045099       0.831429                 0.831281
# 9   0.001243    0.042114       0.871429                 0.871000
# 10  0.115915    0.108272       0.894286                 0.894005
# 11  0.111272    0.102832       0.888571                 0.889370
# 12  0.107032    0.103468       0.871429                 0.878045
# 13  0.108003    0.107782       0.897143                 0.897143
# 14  0.106852    0.101732       0.854286                 0.857880
# 15  0.003307    0.005780       1.000000                 1.000000
# 16  0.003474    0.003935       1.000000                 1.000000
# 17  0.002403    0.003941       1.000000                 1.000000
# 18  0.002341    0.003887       1.000000                 1.000000
# 19  0.002414    0.003845       1.000000                 1.000000
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.900000          0.900495      0.949686  LogReg
# 1               0.908571          0.908114      0.958399  LogReg
# 2               0.902857          0.902585      0.957875  LogReg
# 3               0.902857          0.902763      0.931738  LogReg
# 4               0.877143          0.876920      0.939801  LogReg
# 5               0.860000          0.859723      0.927297     KNN
# 6               0.842857          0.842993      0.924333     KNN
# 7               0.842857          0.842577      0.912929     KNN
# 8               0.831429          0.831348      0.906404     KNN
# 9               0.871429          0.870851      0.941040     KNN
# 10              0.894286          0.893769      0.945891     SVM
# 11              0.888571          0.888071      0.947760     SVM
# 12              0.871429          0.870117      0.939569     SVM
# 13              0.897143          0.897143      0.933916     SVM
# 14              0.854286          0.851310      0.929146     SVM
# 15              1.000000          1.000000      1.000000     GNB
# 16              1.000000          1.000000      1.000000     GNB
# 17              1.000000          1.000000      1.000000     GNB
# 18              1.000000          1.000000      1.000000     GNB
# 19              1.000000          1.000000      1.000000     GNB
# 15.627592839009594

# %%
# 2) THR: %50

df_malicious = pd.concat([df3,df32,df34])
df_benign = pd.concat([df11])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_THR_50_s2 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 26669
# benign: 29010
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 26669
# benign: 29010
# Feature Extraction: 100%|█████████████████████| 157/157 [00:05<00:00, 27.10it/s]
# Feature Extraction: 100%|█████████████████████| 153/153 [00:06<00:00, 23.82it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.95      0.95       712
#       benign       0.95      0.95      0.95       680
#
#     accuracy                           0.95      1392
#    macro avg       0.95      0.95      0.95      1392
# weighted avg       0.95      0.95      0.95      1392
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.153212    0.007816       0.966507                 0.966588
# 1  0.089346    0.006565       0.955689                 0.955775
# 2  0.091914    0.006682       0.950898                 0.950895
# 3  0.107180    0.006625       0.965269                 0.965763
# 4  0.117786    0.006723       0.976048                 0.976065
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.966507          0.966525      0.992982  LogReg
# 1              0.955689          0.955698      0.991754  LogReg
# 2              0.950898          0.950884      0.987081  LogReg
# 3              0.965269          0.965282      0.992220  LogReg
# 4              0.976048          0.976051      0.992142  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.96      0.95      0.95       712
#       benign       0.95      0.95      0.95       680
#
#     accuracy                           0.95      1392
#    macro avg       0.95      0.95      0.95      1392
# weighted avg       0.95      0.95      0.95      1392
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  0.153212    0.007816       0.966507                 0.966588
# 1  0.089346    0.006565       0.955689                 0.955775
# 2  0.091914    0.006682       0.950898                 0.950895
# 3  0.107180    0.006625       0.965269                 0.965763
# 4  0.117786    0.006723       0.976048                 0.976065
# 5  0.004777    0.205481       0.970096                 0.970287
# 6  0.004201    0.196183       0.949701                 0.949904
# 7  0.005900    0.190330       0.954491                 0.954485
# 8  0.004130    0.164237       0.965269                 0.965763
# 9  0.004132    0.175430       0.977246                 0.977279
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.966507          0.966525      0.992982  LogReg
# 1              0.955689          0.955698      0.991754  LogReg
# 2              0.950898          0.950884      0.987081  LogReg
# 3              0.965269          0.965282      0.992220  LogReg
# 4              0.976048          0.976051      0.992142  LogReg
# 5              0.970096          0.970123      0.991706     KNN
# 6              0.949701          0.949715      0.980757     KNN
# 7              0.954491          0.954482      0.988789     KNN
# 8              0.965269          0.965282      0.987873     KNN
# 9              0.977246          0.977249      0.988193     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.94      0.95       712
#       benign       0.94      0.95      0.95       680
#
#     accuracy                           0.95      1392
#    macro avg       0.95      0.95      0.95      1392
# weighted avg       0.95      0.95      0.95      1392
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.153212    0.007816       0.966507                 0.966588
# 1   0.089346    0.006565       0.955689                 0.955775
# 2   0.091914    0.006682       0.950898                 0.950895
# 3   0.107180    0.006625       0.965269                 0.965763
# 4   0.117786    0.006723       0.976048                 0.976065
# 5   0.004777    0.205481       0.970096                 0.970287
# 6   0.004201    0.196183       0.949701                 0.949904
# 7   0.005900    0.190330       0.954491                 0.954485
# 8   0.004130    0.164237       0.965269                 0.965763
# 9   0.004132    0.175430       0.977246                 0.977279
# 10  0.198318    0.156236       0.962919                 0.963503
# 11  0.194666    0.155532       0.964072                 0.964641
# 12  0.187664    0.147225       0.956886                 0.956960
# 13  0.202358    0.163254       0.968862                 0.968862
# 14  0.196760    0.159801       0.967665                 0.968033
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.966507          0.966525      0.992982  LogReg
# 1               0.955689          0.955698      0.991754  LogReg
# 2               0.950898          0.950884      0.987081  LogReg
# 3               0.965269          0.965282      0.992220  LogReg
# 4               0.976048          0.976051      0.992142  LogReg
# 5               0.970096          0.970123      0.991706     KNN
# 6               0.949701          0.949715      0.980757     KNN
# 7               0.954491          0.954482      0.988789     KNN
# 8               0.965269          0.965282      0.987873     KNN
# 9               0.977246          0.977249      0.988193     KNN
# 10              0.962919          0.962976      0.988969     SVM
# 11              0.964072          0.964086      0.986968     SVM
# 12              0.956886          0.956901      0.980440     SVM
# 13              0.968862          0.968862      0.990306     SVM
# 14              0.967665          0.967681      0.992027     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.98      1.00      0.99       712
#       benign       1.00      0.97      0.98       680
#
#     accuracy                           0.98      1392
#    macro avg       0.99      0.98      0.98      1392
# weighted avg       0.99      0.98      0.98      1392
#
#     fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0   0.153212    0.007816       0.966507                 0.966588
# 1   0.089346    0.006565       0.955689                 0.955775
# 2   0.091914    0.006682       0.950898                 0.950895
# 3   0.107180    0.006625       0.965269                 0.965763
# 4   0.117786    0.006723       0.976048                 0.976065
# 5   0.004777    0.205481       0.970096                 0.970287
# 6   0.004201    0.196183       0.949701                 0.949904
# 7   0.005900    0.190330       0.954491                 0.954485
# 8   0.004130    0.164237       0.965269                 0.965763
# 9   0.004132    0.175430       0.977246                 0.977279
# 10  0.198318    0.156236       0.962919                 0.963503
# 11  0.194666    0.155532       0.964072                 0.964641
# 12  0.187664    0.147225       0.956886                 0.956960
# 13  0.202358    0.163254       0.968862                 0.968862
# 14  0.196760    0.159801       0.967665                 0.968033
# 15  0.011864    0.007694       0.994019                 0.994040
# 16  0.013141    0.007313       0.995210                 0.995220
# 17  0.010591    0.007034       0.985629                 0.986003
# 18  0.010527    0.006982       0.986826                 0.987178
# 19  0.010469    0.007008       0.996407                 0.996432
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.966507          0.966525      0.992982  LogReg
# 1               0.955689          0.955698      0.991754  LogReg
# 2               0.950898          0.950884      0.987081  LogReg
# 3               0.965269          0.965282      0.992220  LogReg
# 4               0.976048          0.976051      0.992142  LogReg
# 5               0.970096          0.970123      0.991706     KNN
# 6               0.949701          0.949715      0.980757     KNN
# 7               0.954491          0.954482      0.988789     KNN
# 8               0.965269          0.965282      0.987873     KNN
# 9               0.977246          0.977249      0.988193     KNN
# 10              0.962919          0.962976      0.988969     SVM
# 11              0.964072          0.964086      0.986968     SVM
# 12              0.956886          0.956901      0.980440     SVM
# 13              0.968862          0.968862      0.990306     SVM
# 14              0.967665          0.967681      0.992027     SVM
# 15              0.994019          0.994017      0.997500     GNB
# 16              0.995210          0.995209      0.997572     GNB
# 17              0.985629          0.985610      0.996114     GNB
# 18              0.986826          0.986831      0.998842     GNB
# 19              0.996407          0.996406      0.998717     GNB
# 27.36883158099954

# %%
 # 3) THR: %100
    
df_malicious = pd.concat([df1,df2,df4,df5,df6,df7,df35])
df_benign = pd.concat([df9,df10,df11,df12,df14,df16,df17,df18,df19,df20,df21,df22,df23])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_THR_100_s2 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 1520681
# benign: 1537036
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 1520681
# benign: 1537036
# Feature Extraction: 100%|█████████████████████| 160/160 [04:01<00:00,  1.51s/it]
# Feature Extraction: 100%|█████████████████████| 160/160 [04:10<00:00,  1.56s/it]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.91      0.91      0.91     38397
#       benign       0.91      0.91      0.91     38047
#
#     accuracy                           0.91     76444
#    macro avg       0.91      0.91      0.91     76444
# weighted avg       0.91      0.91      0.91     76444
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.625997    0.125976       0.908560                 0.908596
# 1  5.829456    0.139210       0.912353                 0.912447
# 2  5.390456    0.157464       0.909563                 0.909622
# 3  5.618250    0.126835       0.911111                 0.911110
# 4  5.916398    0.131369       0.912569                 0.912613
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.908560          0.908554      0.968288  LogReg
# 1              0.912353          0.912350      0.969655  LogReg
# 2              0.909563          0.909556      0.968631  LogReg
# 3              0.911111          0.911110      0.969327  LogReg
# 4              0.912569          0.912563      0.970246  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.93      0.95      0.94     38397
#       benign       0.95      0.93      0.94     38047
#
#     accuracy                           0.94     76444
#    macro avg       0.94      0.94      0.94     76444
# weighted avg       0.94      0.94      0.94     76444
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.625997    0.125976       0.908560                 0.908596
# 1  5.829456    0.139210       0.912353                 0.912447
# 2  5.390456    0.157464       0.909563                 0.909622
# 3  5.618250    0.126835       0.911111                 0.911110
# 4  5.916398    0.131369       0.912569                 0.912613
# 5  0.246347  347.555178       0.939934                 0.940155
# 6  0.238807  351.641014       0.939367                 0.939611
# 7  0.285311  347.789643       0.940261                 0.940437
# 8  0.269351  385.582140       0.940980                 0.941164
# 9  0.303725  356.688932       0.939954                 0.940209
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.908560          0.908554      0.968288  LogReg
# 1              0.912353          0.912350      0.969655  LogReg
# 2              0.909563          0.909556      0.968631  LogReg
# 3              0.911111          0.911110      0.969327  LogReg
# 4              0.912569          0.912563      0.970246  LogReg
# 5              0.939934          0.939921      0.975891     KNN
# 6              0.939367          0.939360      0.975708     KNN
# 7              0.940261          0.940251      0.976513     KNN
# 8              0.940980          0.940968      0.977027     KNN
# 9              0.939954          0.939940      0.975717     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.92      0.95      0.93     38397
#       benign       0.94      0.92      0.93     38047
#
#     accuracy                           0.93     76444
#    macro avg       0.93      0.93      0.93     76444
# weighted avg       0.93      0.93      0.93     76444
#
#        fit_time   score_time  test_accuracy  test_precision_weighted  \
# 0      5.625997     0.125976       0.908560                 0.908596
# 1      5.829456     0.139210       0.912353                 0.912447
# 2      5.390456     0.157464       0.909563                 0.909622
# 3      5.618250     0.126835       0.911111                 0.911110
# 4      5.916398     0.131369       0.912569                 0.912613
# 5      0.246347   347.555178       0.939934                 0.940155
# 6      0.238807   351.641014       0.939367                 0.939611
# 7      0.285311   347.789643       0.940261                 0.940437
# 8      0.269351   385.582140       0.940980                 0.941164
# 9      0.303725   356.688932       0.939954                 0.940209
# 10  2491.346207  1029.369125       0.929730                 0.929976
# 11  2285.164796  1035.067950       0.930973                 0.931275
# 12  2281.159824  1032.371579       0.930035                 0.930311
# 13  2341.676313  1114.172351       0.933633                 0.933982
# 14  2332.182127  1072.507989       0.932912                 0.933301
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.908560          0.908554      0.968288  LogReg
# 1               0.912353          0.912350      0.969655  LogReg
# 2               0.909563          0.909556      0.968631  LogReg
# 3               0.911111          0.911110      0.969327  LogReg
# 4               0.912569          0.912563      0.970246  LogReg
# 5               0.939934          0.939921      0.975891     KNN
# 6               0.939367          0.939360      0.975708     KNN
# 7               0.940261          0.940251      0.976513     KNN
# 8               0.940980          0.940968      0.977027     KNN
# 9               0.939954          0.939940      0.975717     KNN
# 10              0.929730          0.929714      0.977279     SVM
# 11              0.930973          0.930963      0.978053     SVM
# 12              0.930035          0.930019      0.977678     SVM
# 13              0.933633          0.933609      0.979225     SVM
# 14              0.932912          0.932888      0.977803     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.87      0.93      0.90     38397
#       benign       0.93      0.85      0.89     38047
#
#     accuracy                           0.89     76444
#    macro avg       0.90      0.89      0.89     76444
# weighted avg       0.90      0.89      0.89     76444
#
#        fit_time   score_time  test_accuracy  test_precision_weighted  \
# 0      5.625997     0.125976       0.908560                 0.908596
# 1      5.829456     0.139210       0.912353                 0.912447
# 2      5.390456     0.157464       0.909563                 0.909622
# 3      5.618250     0.126835       0.911111                 0.911110
# 4      5.916398     0.131369       0.912569                 0.912613
# 5      0.246347   347.555178       0.939934                 0.940155
# 6      0.238807   351.641014       0.939367                 0.939611
# 7      0.285311   347.789643       0.940261                 0.940437
# 8      0.269351   385.582140       0.940980                 0.941164
# 9      0.303725   356.688932       0.939954                 0.940209
# 10  2491.346207  1029.369125       0.929730                 0.929976
# 11  2285.164796  1035.067950       0.930973                 0.931275
# 12  2281.159824  1032.371579       0.930035                 0.930311
# 13  2341.676313  1114.172351       0.933633                 0.933982
# 14  2332.182127  1072.507989       0.932912                 0.933301
# 15     1.009175     0.322823       0.891052                 0.893147
# 16     0.957259     0.317327       0.900689                 0.904110
# 17     0.949991     0.303168       0.890006                 0.891817
# 18     0.926090     0.305426       0.896241                 0.898538
# 19     0.924609     0.307705       0.892532                 0.894806
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.908560          0.908554      0.968288  LogReg
# 1               0.912353          0.912350      0.969655  LogReg
# 2               0.909563          0.909556      0.968631  LogReg
# 3               0.911111          0.911110      0.969327  LogReg
# 4               0.912569          0.912563      0.970246  LogReg
# 5               0.939934          0.939921      0.975891     KNN
# 6               0.939367          0.939360      0.975708     KNN
# 7               0.940261          0.940251      0.976513     KNN
# 8               0.940980          0.940968      0.977027     KNN
# 9               0.939954          0.939940      0.975717     KNN
# 10              0.929730          0.929714      0.977279     SVM
# 11              0.930973          0.930963      0.978053     SVM
# 12              0.930035          0.930019      0.977678     SVM
# 13              0.933633          0.933609      0.979225     SVM
# 14              0.932912          0.932888      0.977803     SVM
# 15              0.891052          0.890875      0.930846     GNB
# 16              0.900689          0.900488      0.947271     GNB
# 17              0.890006          0.889854      0.927202     GNB
# 18              0.896241          0.896048      0.935342     GNB
# 19              0.892532          0.892342      0.930542     GNB
# 25203.359696525004

# %%
## S3; In-browser VS Binary ##

  #1) In-Browser
df_malicious = pd.concat([df3,df5,df6,df7,df32,df33,df34,df35])
df_benign = pd.concat([df10,df20,df21])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_In_s3 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 305874
# benign: 314906
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 305874
# benign: 314906
# Feature Extraction: 100%|█████████████████████| 160/160 [00:47<00:00,  3.38it/s]
# Feature Extraction: 100%|█████████████████████| 160/160 [00:47<00:00,  3.34it/s]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.92      0.94      7914
#       benign       0.92      0.95      0.93      7606
#
#     accuracy                           0.93     15520
#    macro avg       0.94      0.94      0.93     15520
# weighted avg       0.94      0.93      0.93     15520
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.188392    0.028686       0.938681                 0.939056
# 1  1.195529    0.028272       0.937715                 0.938205
# 2  1.288743    0.026587       0.936211                 0.937253
# 3  1.161321    0.026850       0.934815                 0.935246
# 4  1.374185    0.028503       0.939104                 0.939371
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.938681          0.938671      0.982871  LogReg
# 1              0.937715          0.937710      0.981675  LogReg
# 2              0.936211          0.936219      0.983128  LogReg
# 3              0.934815          0.934816      0.982469  LogReg
# 4              0.939104          0.939099      0.983409  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.94      0.95      7914
#       benign       0.94      0.95      0.95      7606
#
#     accuracy                           0.95     15520
#    macro avg       0.95      0.95      0.95     15520
# weighted avg       0.95      0.95      0.95     15520
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  1.188392    0.028686       0.938681                 0.939056
# 1  1.195529    0.028272       0.937715                 0.938205
# 2  1.288743    0.026587       0.936211                 0.937253
# 3  1.161321    0.026850       0.934815                 0.935246
# 4  1.374185    0.028503       0.939104                 0.939371
# 5  0.061003   14.843662       0.953071                 0.953073
# 6  0.046322   13.756846       0.949098                 0.949285
# 7  0.061440   13.938449       0.948454                 0.948641
# 8  0.057029   14.252710       0.951246                 0.951414
# 9  0.052634   13.283071       0.951777                 0.951788
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.938681          0.938671      0.982871  LogReg
# 1              0.937715          0.937710      0.981675  LogReg
# 2              0.936211          0.936219      0.983128  LogReg
# 3              0.934815          0.934816      0.982469  LogReg
# 4              0.939104          0.939099      0.983409  LogReg
# 5              0.953071          0.953071      0.983692     KNN
# 6              0.949098          0.949099      0.982195     KNN
# 7              0.948454          0.948463      0.980441     KNN
# 8              0.951246          0.951249      0.983010     KNN
# 9              0.951777          0.951778      0.983954     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.97      0.93      0.95      7914
#       benign       0.93      0.96      0.95      7606
#
#     accuracy                           0.95     15520
#    macro avg       0.95      0.95      0.95     15520
# weighted avg       0.95      0.95      0.95     15520
#
#      fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0    1.188392    0.028686       0.938681                 0.939056
# 1    1.195529    0.028272       0.937715                 0.938205
# 2    1.288743    0.026587       0.936211                 0.937253
# 3    1.161321    0.026850       0.934815                 0.935246
# 4    1.374185    0.028503       0.939104                 0.939371
# 5    0.061003   14.843662       0.953071                 0.953073
# 6    0.046322   13.756846       0.949098                 0.949285
# 7    0.061440   13.938449       0.948454                 0.948641
# 8    0.057029   14.252710       0.951246                 0.951414
# 9    0.052634   13.283071       0.951777                 0.951788
# 10  65.382123   27.312555       0.951246                 0.951466
# 11  68.526090   27.242387       0.951246                 0.951732
# 12  66.253523   27.060328       0.950064                 0.951108
# 13  66.864752   26.884395       0.950601                 0.951202
# 14  67.205470   27.124804       0.955214                 0.955479
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.938681          0.938671      0.982871  LogReg
# 1               0.937715          0.937710      0.981675  LogReg
# 2               0.936211          0.936219      0.983128  LogReg
# 3               0.934815          0.934816      0.982469  LogReg
# 4               0.939104          0.939099      0.983409  LogReg
# 5               0.953071          0.953071      0.983692     KNN
# 6               0.949098          0.949099      0.982195     KNN
# 7               0.948454          0.948463      0.980441     KNN
# 8               0.951246          0.951249      0.983010     KNN
# 9               0.951777          0.951778      0.983954     KNN
# 10              0.951246          0.951242      0.987235     SVM
# 11              0.951246          0.951242      0.986394     SVM
# 12              0.950064          0.950070      0.986300     SVM
# 13              0.950601          0.950600      0.987904     SVM
# 14              0.955214          0.955211      0.987452     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.99      0.99      0.99      7914
#       benign       0.99      0.99      0.99      7606
#
#     accuracy                           0.99     15520
#    macro avg       0.99      0.99      0.99     15520
# weighted avg       0.99      0.99      0.99     15520
#
#      fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0    1.188392    0.028686       0.938681                 0.939056
# 1    1.195529    0.028272       0.937715                 0.938205
# 2    1.288743    0.026587       0.936211                 0.937253
# 3    1.161321    0.026850       0.934815                 0.935246
# 4    1.374185    0.028503       0.939104                 0.939371
# 5    0.061003   14.843662       0.953071                 0.953073
# 6    0.046322   13.756846       0.949098                 0.949285
# 7    0.061440   13.938449       0.948454                 0.948641
# 8    0.057029   14.252710       0.951246                 0.951414
# 9    0.052634   13.283071       0.951777                 0.951788
# 10  65.382123   27.312555       0.951246                 0.951466
# 11  68.526090   27.242387       0.951246                 0.951732
# 12  66.253523   27.060328       0.950064                 0.951108
# 13  66.864752   26.884395       0.950601                 0.951202
# 14  67.205470   27.124804       0.955214                 0.955479
# 15   0.203574    0.069522       0.987758                 0.987762
# 16   0.175836    0.061209       0.988832                 0.988839
# 17   0.171797    0.060884       0.990228                 0.990229
# 18   0.171490    0.061321       0.990979                 0.990980
# 19   0.171811    0.060838       0.989153                 0.989155
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.938681          0.938671      0.982871  LogReg
# 1               0.937715          0.937710      0.981675  LogReg
# 2               0.936211          0.936219      0.983128  LogReg
# 3               0.934815          0.934816      0.982469  LogReg
# 4               0.939104          0.939099      0.983409  LogReg
# 5               0.953071          0.953071      0.983692     KNN
# 6               0.949098          0.949099      0.982195     KNN
# 7               0.948454          0.948463      0.980441     KNN
# 8               0.951246          0.951249      0.983010     KNN
# 9               0.951777          0.951778      0.983954     KNN
# 10              0.951246          0.951242      0.987235     SVM
# 11              0.951246          0.951242      0.986394     SVM
# 12              0.950064          0.950070      0.986300     SVM
# 13              0.950601          0.950600      0.987904     SVM
# 14              0.955214          0.955211      0.987452     SVM
# 15              0.987758          0.987758      0.992736     GNB
# 16              0.988832          0.988832      0.992940     GNB
# 17              0.990228          0.990227      0.995182     GNB
# 18              0.990979          0.990979      0.994982     GNB
# 19              0.989153          0.989153      0.994766     GNB
# 884.8174335829972

# %%
#2) Binary
df_malicious = pd.concat([df1,df2,df4])
df_benign = pd.concat([df11,df12,df10,df18,df20,df21,df22,df23])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

start = timer()

results_Host_s3 = run_process(df_malicious,df_benign,df_results)


end = timer()
print(end - start)
# Out:
# malicious: 1251356
# benign: 1229399
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 1251356
# benign: 1229399
# Feature Extraction: 100%|█████████████████████| 160/160 [03:16<00:00,  1.23s/it]
# Feature Extraction: 100%|█████████████████████| 160/160 [03:19<00:00,  1.25s/it]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.96      0.97     30787
#       benign       0.96      0.98      0.97     31232
#
#     accuracy                           0.97     62019
#    macro avg       0.97      0.97      0.97     62019
# weighted avg       0.97      0.97      0.97     62019
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  4.518209    0.099288       0.967054                 0.967212
# 1  4.409531    0.098000       0.966301                 0.966449
# 2  4.462255    0.099581       0.965682                 0.965834
# 3  4.365292    0.111827       0.967080                 0.967250
# 4  4.271812    0.097730       0.966865                 0.966988
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.967054          0.967049      0.993350  LogReg
# 1              0.966301          0.966294      0.993634  LogReg
# 2              0.965682          0.965679      0.993647  LogReg
# 3              0.967080          0.967073      0.993797  LogReg
# 4              0.966865          0.966858      0.993685  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.97      0.98     30787
#       benign       0.97      0.98      0.98     31232
#
#     accuracy                           0.98     62019
#    macro avg       0.98      0.98      0.98     62019
# weighted avg       0.98      0.98      0.98     62019
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  4.518209    0.099288       0.967054                 0.967212
# 1  4.409531    0.098000       0.966301                 0.966449
# 2  4.462255    0.099581       0.965682                 0.965834
# 3  4.365292    0.111827       0.967080                 0.967250
# 4  4.271812    0.097730       0.966865                 0.966988
# 5  0.208164  234.018480       0.973046                 0.973067
# 6  0.257562  243.594358       0.973718                 0.973734
# 7  0.276767  231.526486       0.973852                 0.973901
# 8  0.260805  246.276957       0.974551                 0.974599
# 9  0.273056  253.015730       0.974846                 0.974857
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.967054          0.967049      0.993350  LogReg
# 1              0.966301          0.966294      0.993634  LogReg
# 2              0.965682          0.965679      0.993647  LogReg
# 3              0.967080          0.967073      0.993797  LogReg
# 4              0.966865          0.966858      0.993685  LogReg
# 5              0.973046          0.973046      0.990824     KNN
# 6              0.973718          0.973717      0.991043     KNN
# 7              0.973852          0.973851      0.991208     KNN
# 8              0.974551          0.974548      0.991175     KNN
# 9              0.974846          0.974845      0.990666     KNN
# SVM
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.96      0.97     30787
#       benign       0.97      0.98      0.97     31232
#
#     accuracy                           0.97     62019
#    macro avg       0.97      0.97      0.97     62019
# weighted avg       0.97      0.97      0.97     62019
#
#       fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0     4.518209    0.099288       0.967054                 0.967212
# 1     4.409531    0.098000       0.966301                 0.966449
# 2     4.462255    0.099581       0.965682                 0.965834
# 3     4.365292    0.111827       0.967080                 0.967250
# 4     4.271812    0.097730       0.966865                 0.966988
# 5     0.208164  234.018480       0.973046                 0.973067
# 6     0.257562  243.594358       0.973718                 0.973734
# 7     0.276767  231.526486       0.973852                 0.973901
# 8     0.260805  246.276957       0.974551                 0.974599
# 9     0.273056  253.015730       0.974846                 0.974857
# 10  671.235434  272.872142       0.969848                 0.969938
# 11  672.373102  273.944459       0.970037                 0.970153
# 12  687.720469  273.733247       0.970385                 0.970488
# 13  667.376138  275.649489       0.970412                 0.970559
# 14  659.665939  274.076639       0.970627                 0.970715
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.967054          0.967049      0.993350  LogReg
# 1               0.966301          0.966294      0.993634  LogReg
# 2               0.965682          0.965679      0.993647  LogReg
# 3               0.967080          0.967073      0.993797  LogReg
# 4               0.966865          0.966858      0.993685  LogReg
# 5               0.973046          0.973046      0.990824     KNN
# 6               0.973718          0.973717      0.991043     KNN
# 7               0.973852          0.973851      0.991208     KNN
# 8               0.974551          0.974548      0.991175     KNN
# 9               0.974846          0.974845      0.990666     KNN
# 10              0.969848          0.969846      0.993882     SVM
# 11              0.970037          0.970031      0.993924     SVM
# 12              0.970385          0.970383      0.994218     SVM
# 13              0.970412          0.970407      0.994703     SVM
# 14              0.970627          0.970622      0.994300     SVM
# GNB
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.93      0.96     30787
#       benign       0.93      0.98      0.96     31232
#
#     accuracy                           0.96     62019
#    macro avg       0.96      0.96      0.96     62019
# weighted avg       0.96      0.96      0.96     62019
#
#       fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0     4.518209    0.099288       0.967054                 0.967212
# 1     4.409531    0.098000       0.966301                 0.966449
# 2     4.462255    0.099581       0.965682                 0.965834
# 3     4.365292    0.111827       0.967080                 0.967250
# 4     4.271812    0.097730       0.966865                 0.966988
# 5     0.208164  234.018480       0.973046                 0.973067
# 6     0.257562  243.594358       0.973718                 0.973734
# 7     0.276767  231.526486       0.973852                 0.973901
# 8     0.260805  246.276957       0.974551                 0.974599
# 9     0.273056  253.015730       0.974846                 0.974857
# 10  671.235434  272.872142       0.969848                 0.969938
# 11  672.373102  273.944459       0.970037                 0.970153
# 12  687.720469  273.733247       0.970385                 0.970488
# 13  667.376138  275.649489       0.970412                 0.970559
# 14  659.665939  274.076639       0.970627                 0.970715
# 15    0.881025    0.297513       0.954800                 0.956120
# 16    0.753547    0.245790       0.954638                 0.955942
# 17    0.752063    0.250558       0.954610                 0.955858
# 18    0.751071    0.245172       0.955927                 0.957223
# 19    0.750871    0.247904       0.954556                 0.955788
#
#     test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0               0.967054          0.967049      0.993350  LogReg
# 1               0.966301          0.966294      0.993634  LogReg
# 2               0.965682          0.965679      0.993647  LogReg
# 3               0.967080          0.967073      0.993797  LogReg
# 4               0.966865          0.966858      0.993685  LogReg
# 5               0.973046          0.973046      0.990824     KNN
# 6               0.973718          0.973717      0.991043     KNN
# 7               0.973852          0.973851      0.991208     KNN
# 8               0.974551          0.974548      0.991175     KNN
# 9               0.974846          0.974845      0.990666     KNN
# 10              0.969848          0.969846      0.993882     SVM
# 11              0.970037          0.970031      0.993924     SVM
# 12              0.970385          0.970383      0.994218     SVM
# 13              0.970412          0.970407      0.994703     SVM
# 14              0.970627          0.970622      0.994300     SVM
# 15              0.954800          0.954760      0.959995     GNB
# 16              0.954638          0.954589      0.959665     GNB
# 17              0.954610          0.954577      0.959873     GNB
# 18              0.955927          0.955882      0.960716     GNB
# 19              0.954556          0.954506      0.958982     GNB
# 8526.365571514005

# %%
## S4: Fully compromised (All)
 
df_malicious = pd.concat([df1,df2,df3,df4,df5,df6,df7,df32,df33,df34,df35])
 
df_benign = pd.concat([df8,df13,df18,df20,df21,df22])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))


start = timer()

results_all_combined_s0 = run_process(df_malicious,df_benign,df_results)

end = timer()
print(end - start)
# Out:
# malicious: 1557230
# benign: 1561443
# 0 NAN in malicious!
# 0 NAN in benign!
# After droppping NAN rows:
# malicious: 1557230
# benign: 1561443
# Feature Extraction: 100%|█████████████████████| 160/160 [04:04<00:00,  1.53s/it]
# Feature Extraction: 100%|█████████████████████| 160/160 [04:10<00:00,  1.57s/it]
# let the ml starts
# LogReg
#               precision    recall  f1-score   support
#
#    malignant       0.92      0.94      0.93     38930
#       benign       0.94      0.92      0.93     39037
#
#     accuracy                           0.93     77967
#    macro avg       0.93      0.93      0.93     77967
# weighted avg       0.93      0.93      0.93     77967
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.764418    0.123413       0.931211                 0.931397
# 1  5.851226    0.123470       0.931103                 0.931307
# 2  5.223877    0.164393       0.931744                 0.931859
# 3  5.307401    0.155300       0.929286                 0.929515
# 4  5.563336    0.159430       0.930611                 0.930782
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.931211          0.931205      0.979117  LogReg
# 1              0.931103          0.931094      0.978357  LogReg
# 2              0.931744          0.931738      0.978361  LogReg
# 3              0.929286          0.929269      0.977272  LogReg
# 4              0.930611          0.930604      0.978508  LogReg
# KNN
#               precision    recall  f1-score   support
#
#    malignant       0.94      0.96      0.95     38930
#       benign       0.96      0.94      0.95     39037
#
#     accuracy                           0.95     77967
#    macro avg       0.95      0.95      0.95     77967
# weighted avg       0.95      0.95      0.95     77967
#
#    fit_time  score_time  test_accuracy  test_precision_weighted  \
# 0  5.764418    0.123413       0.931211                 0.931397
# 1  5.851226    0.123470       0.931103                 0.931307
# 2  5.223877    0.164393       0.931744                 0.931859
# 3  5.307401    0.155300       0.929286                 0.929515
# 4  5.563336    0.159430       0.930611                 0.930782
# 5  0.256376  364.371731       0.951369                 0.951507
# 6  0.232918  392.946271       0.952223                 0.952407
# 7  0.238687  384.393863       0.951710                 0.951817
# 8  0.228359  371.206566       0.951603                 0.951749
# 9  0.282023  387.173192       0.951475                 0.951648
#
#    test_recall_weighted  test_f1_weighted  test_roc_auc   model
# 0              0.931211          0.931205      0.979117  LogReg
# 1              0.931103          0.931094      0.978357  LogReg
# 2              0.931744          0.931738      0.978361  LogReg
# 3              0.929286          0.929269      0.977272  LogReg
# 4              0.930611          0.930604      0.978508  LogReg
# 5              0.951369          0.951366      0.981046     KNN
# 6              0.952223          0.952218      0.982188     KNN
# 7              0.951710          0.951706      0.981420     KNN
# 8              0.951603          0.951596      0.981378     KNN
# 9              0.951475          0.951470      0.981729     KNN

# %%
## S5: Partially compromised (IoT + Laptop)
 
df_malicious = pd.concat([df5,df35])
 
df_benign = pd.concat([df9,df15,df11])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))


start = timer()

results_all_combined_s0 = run_process(df_malicious,df_benign,df_results)

end = timer()
print(end - start)

# %%
## S6: Single compromised (IoT) (WebOS)
 
df_malicious = pd.concat([df1])
 
df_benign = pd.concat([df22])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))


start = timer()

results_all_combined_s0 = run_process(df_malicious,df_benign,df_results)

end = timer()
print(end - start)

# %%
## S7: IoT compromised (IoT + IoT)
 
df_malicious = pd.concat([df1,df6])
 
df_benign = pd.concat([df19,df22])

print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))

print("{} NAN in malicious!".format(len(df_malicious[df_malicious.isna().any(axis=1)])))
print("{} NAN in benign!".format(len(df_benign[df_benign.isna().any(axis=1)])))

df_malicious = df_malicious.dropna()
df_benign = df_benign.dropna()

print("After droppping NAN rows: ")
print("malicious: {}".format(len(df_malicious)))
print("benign: {}".format(len(df_benign)))


start = timer()

results_all_combined_s0 = run_process(df_malicious,df_benign,df_results)

end = timer()
print(end - start)
